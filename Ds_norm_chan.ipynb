# %%
#SELECTION DEFINITION



Ds_SELECTION_old = (
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PT > 550) & (mm_PT > 550) & "
    "(Jpsi_M < 3150) & (Jpsi_M > 3040) & "
    "(Jpsi_ENDVERTEX_CHI2 < 9.) &"
    # "(pi_PT > 1700.) & "
    "(pi_TRACK_CHI2NDOF < 3.) & "
    "(pi_ProbNNghost < 0.4) &"
    "(pi_IPCHI2_OWNPV > 3) &"
    "(Bc_ENDVERTEX_CHI2 < 9.) & "
    "(Bc_IPCHI2_OWNPV < 25.) & "
    # "(Kp_PT > 1000.) & (Km_PT > 1000.) &"
    "(Kp_P > 1000.) & (Km_P > 1000.) &"
    "(pi_P > 1000.) & "
    "(Ds_ENDVERTEX_CHI2 < 16.) &"
    "(Ds_PT > 1000.) &"
    "(Ds_M > 1944) & (Ds_M < 1994) &"
    "(Bc_DIRA_OWNPV > 0.99)"
)
Ds_SELECTION_new_old = (
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PT > 550) & (mm_PT > 550) & "
    "(Jpsi_M < 3150) & (Jpsi_M > 3040) & "
    "(Jpsi_ENDVERTEX_CHI2 < 9.) &"
    "(pi_PT > 500.) & "
    "(pi_TRACK_CHI2NDOF < 3.) & "
    "(pi_ProbNNghost < 0.4) &"
    "(pi_IPCHI2_OWNPV > 3) &"
    "(Bc_ENDVERTEX_CHI2 < 9.) & "
    "(Bc_IPCHI2_OWNPV < 25.) & "
    "(Kp_PT > 500.) & (Km_PT > 500.) &"
    "(Kp_P > 500.) & (Km_P > 500.) &"
    "(pi_P > 500.) & "
    "(Ds_ENDVERTEX_CHI2 < 9.) &"
    "(Ds_PT > 1000.) &"
    "(Ds_M > 1944) & (Ds_M < 1994) &"
    "(Bc_DIRA_OWNPV > 0.99) "
    # "(Bc_FullDTF_M > 0.)"
)
Ds_SELECTION_new = (
    # table 13
    "(Ds_ENDVERTEX_CHI2 < 16.) &"
    "(Ds_PT > 1000.) &"
    "(Ds_M > 1943) & (Ds_M < 1993) &"
    "(Bc_ENDVERTEX_CHI2 < 9.) & "
    "(Bc_IPCHI2_OWNPV < 25.) & "
    "(Bc_DIRA_OWNPV > 0.99) &"
    "((Kp_IPCHI2_OWNPV + Km_IPCHI2_OWNPV + pi_IPCHI2_OWNPV) > 9) & "
    # table 6
    "(mp_isMuon == 1) & (mm_isMuon == 1) &"
    "(mp_TRACK_CHI2NDOF < 3) & (mm_TRACK_CHI2NDOF < 3) &"
    # "(mp_RichDLLpi > 0) & (mm_RichDLLpi > 0) &"
    "(mp_PT > 550) & (mm_PT > 550) &"

    "(Jpsi_M > 3040) & (Jpsi_M < 3140) &"
    "(Jpsi_ENDVERTEX_CHI2 < 9) &"

    # "(pi_PT > 1000) &"
    # "(pi_TRACK_CHI2NDOF < 3) &"
    # "(pi_TRACK_GhostProb < 0.4) &"
    # "(pi_IPCHI2_OWNPV > 9) &"

    "(Bc_ENDVERTEX_CHI2 < 9) &"
    "(Bc_IPCHI2_OWNPV < 25) &"

    # # table 7
    # "(mp_PT > 500) & (mm_PT > 500) &"
    # "(Jpsi_M > 3010) & (Jpsi_M < 3170) &"
    # "(Jpsi_ENDVERTEX_CHI2 < 16) &"
    # "(Bc_ENDVERTEX_CHI2 < 10) &"
    # # "(Bc_M > 5200) & (Bc_M < 5550) &"

    # # table 8
    # "(Kp_TRACK_CHI2NDOF < 3.) & (Km_TRACK_CHI2NDOF < 3.) & (pi_TRACK_CHI2NDOF < 3.) & "
    # "(Kp_PT > 100.) & (Km_PT > 100.) & (pi_PT > 100.) & "
    # "(Kp_P > 1000.) & (Km_P > 1000.) & (pi_P > 1000.) & "
    # "(Kp_MINIPCHI2 > 4) & (Km_MINIPCHI2 > 4) & (pi_MINIPCHI2 > 4) & "
    # "((Kp_PT + Km_PT + pi_PT) > 1800.) & "
    # "(Ds_ENDVERTEX_CHI2 < 10) &"
    # "(Ds_DIRA_OWNPV > 0) &"
    # # "(Kp_RichDLLpi > -10) & (Km_RichDLLpi > -10) & "
    # # "(pi_RichDLLpi < 20) &"
    # "(Ds_M > 1943.49) & (Ds_M < 1993.49) &"
    # "(Bc_PT > 5000) &"
    # # "(Bc_M > 5300) & (Bc_M < 5950) &"
    # "(Bc_ENDVERTEX_CHI2 < 10) &"

    # table 9
    "(mp_TRACK_CHI2NDOF < 3) & (mm_TRACK_CHI2NDOF < 3) &"
    "(mp_isMuon == 1) & (mm_isMuon == 1) &"
    # "(mp_RichDLLpi > 0) & (mm_RichDLLpi > 0) &"
    "(mp_PT > 550) & (mm_PT > 550) &"
    "(mp_IPCHI2_OWNPV > 4) & (mm_IPCHI2_OWNPV > 4) &"
    "(Jpsi_M > 3040) & (Jpsi_M < 3140) &"
    "(Jpsi_ENDVERTEX_CHI2 < 9) &"

    # table 10
    "(pi_TRACK_CHI2NDOF < 3) &"
    "(pi_TRACK_GhostProb < 0.4) &"
    "(pi_PT > 200) &"
    "(pi_ProbNNpi > 0.2) &"
    "(pi_ProbNNk < 0.5) &"
    "(Kp_TRACK_CHI2NDOF < 3.) & (Km_TRACK_CHI2NDOF < 3.) &"
    "(Kp_TRACK_GhostProb < 0.4) & (Km_TRACK_GhostProb < 0.4) &"
    "(Kp_PT > 200) & (Km_PT > 200) &"
    "(Kp_ProbNNk > 0.1) & (Km_ProbNNk > 0.1) "



    # "(Kp_PT > 900) & (Km_PT > 900) & (pi_PT > 900)"

)

Ds_looser_SELECTION = (
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PT > 350) & (mm_PT > 350) & "
    "(Jpsi_M < 3150) & (Jpsi_M > 3040) & "
    "(Jpsi_ENDVERTEX_CHI2 < 11.) &"
    "(pi_PT > 1500.) & "
    "(pi_TRACK_CHI2NDOF < 3.) & "
    "(pi_ProbNNghost < 0.7) &"
    "(pi_IPCHI2_OWNPV > 7) &"
    "(Bc_ENDVERTEX_CHI2 < 11.) & "
    "(Bc_IPCHI2_OWNPV < 27.) & "
    "(Kp_PT > 700.) & (Km_PT > 700.) &"
    "(Kp_P > 700.) & (Km_P > 700.) &"
    "(pi_P > 700.) & "
    "(Ds_ENDVERTEX_CHI2 < 17.) &"
    "(Ds_PT > 700.) &"
    "(Ds_M > 1944) & (Ds_M < 1994) &"
    "(Bc_DIRA_OWNPV > 0.79)"
)
Ds_TRUE_SELECTION = (
    "(Ds_ENDVERTEX_CHI2 < 16.) &"
    "(Ds_PT > 1000.) &"
    "(Ds_M > 1950) & (Ds_M < 1986) &"
    "(Bc_ENDVERTEX_CHI2 < 9.) & "
    "(Bc_IPCHI2_OWNPV < 25.) & "
    "(Bc_DIRA_OWNPV > 0.99)"
)

# %%
#IMPORTING LIBRARIES
import uproot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import mean
from numpy import std
import zfit

from xgboost import XGBClassifier, callback, plot_importance
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import StandardScaler
import pickle
import optuna
import joblib
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
import random 

from hepstats.hypotests.calculators import AsymptoticCalculator
from hepstats.hypotests import Discovery
from hepstats.hypotests.parameters import POI
# Out:
# /afs/cern.ch/user/k/ktrofimi/.venv/lib64/python3.9/site-packages/zfit/__init__.py:60: UserWarning: TensorFlow warnings are by default suppressed by zfit. In order to show them, set the environment variable ZFIT_DISABLE_TF_WARNINGS=0. In order to suppress the TensorFlow warnings AND this warning, set ZFIT_DISABLE_TF_WARNINGS=1.
#   warnings.warn(
# 2025-03-12 14:50:42.673777: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741787445.829231 3710919 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
#LOADING DATASET

files_real_data = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2011_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2012_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2015_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2016_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2017_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2018_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2018_MagUp.root',
]
files_simu_data = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2011_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2012_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2015_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2016_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2017_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2018_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2018_MagUp.root',
]
real_data = uproot.concatenate(files_real_data, cut = Ds_SELECTION_new, library='pd')
simu_data = uproot.concatenate(files_simu_data, cut = Ds_SELECTION_new, library='pd')

# %%
real_data_full = uproot.concatenate(files_real_data, library='pd')

# %%
print(len(real_data_full))
print(len(real_data))
print(len(simu_data))
print(len(simu_data.query(f"{Ds_SELECTION_new} & (Bc_BKGCAT == 0)")))
# Out:
# 428477
# 348856
# 218049
# 187244

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data['pi_PT'], bins=100, range = (250, 3000), density = True, histtype='step', label='simu pi_PT')
ax.hist(real_data['pi_PT'], bins=100, range = (250, 3000), density = True, histtype='step', label='real pi_PT')

ax.set_xlabel('pi_PT')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('pi_PT comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data['Kp_PT'], bins=100, range = (250, 3000), density = True, histtype='step', label='simu Kp_PT')
ax.hist(real_data['Kp_PT'], bins=100, range = (250, 3000), density = True, histtype='step', label='real Kp_PT')

ax.set_xlabel('Kp_PT')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Kp_PT comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data['Km_PT'], bins=100, range = (250, 3000), density = True, histtype='step', label='simu Km_PT')
ax.hist(real_data['Km_PT'], bins=100, range = (250, 3000), density = True, histtype='step', label='real Km_PT')

ax.set_xlabel('Km_PT')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Km_PT comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data['Ds_ENDVERTEX_CHI2'], bins=100, range = (1, 25), density = True, histtype='step', label='simu Ds_ENDVERTEX_CHI2')
ax.hist(real_data['Ds_ENDVERTEX_CHI2'], bins=100, range = (1, 25), density = True, histtype='step', label='real Ds_ENDVERTEX_CHI2')

ax.set_xlabel('Ds_ENDVERTEX_CHI2')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Ds_ENDVERTEX_CHI2 comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.hist(simu_data['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='simu data full')
axes.hist(simu_data.query('(mp_PT > 550) & (mm_PT > 550)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(mp_PT > 550) & (mm_PT > 550)')
axes.hist(simu_data.query('(Jpsi_M < 3150) & (Jpsi_M > 3040)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Jpsi_M < 3150) & (Jpsi_M > 3040)')
axes.hist(simu_data.query('(Jpsi_ENDVERTEX_CHI2 < 9.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Jpsi_ENDVERTEX_CHI2 < 9.)')
# axes.hist(simu_data.query('(pi_PT > 1700.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(pi_PT > 1700.)')
axes.hist(simu_data.query('(pi_TRACK_CHI2NDOF < 3.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(pi_TRACK_CHI2NDOF < 3.)')
axes.hist(simu_data.query('(pi_ProbNNghost < 0.4)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(pi_ProbNNghost < 0.4)')
axes.hist(simu_data.query('(pi_IPCHI2_OWNPV > 9)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(pi_IPCHI2_OWNPV > 9)')
axes.hist(simu_data.query('(Bc_ENDVERTEX_CHI2 < 9.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Bc_ENDVERTEX_CHI2 < 9.)')
axes.hist(simu_data.query('(Bc_IPCHI2_OWNPV < 25.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Bc_IPCHI2_OWNPV < 25.)')
# axes.hist(simu_data.query('(Kp_PT > 1000.) & (Km_PT > 1000.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Kp_PT > 1000.) & (Km_PT > 1000.)')
axes.hist(simu_data.query('(Kp_P > 1000.) & (Km_P > 1000.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Kp_P > 1000.) & (Km_P > 1000.)')
axes.hist(simu_data.query('(pi_P > 1000.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(pi_P > 1000.)')
axes.hist(simu_data.query('(Ds_ENDVERTEX_CHI2 < 16.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Ds_ENDVERTEX_CHI2 < 16.)')
axes.hist(simu_data.query('(Ds_PT > 1000.)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Ds_PT > 1000.)')
axes.hist(simu_data.query('(Ds_M > 1944) & (Ds_M < 1994)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Ds_M > 1944) & (Ds_M < 1994)')
axes.hist(simu_data.query('(Bc_DIRA_OWNPV > 0.99)')['Ds_M'], range = (1850, 2100), bins=100, histtype='step', label='(Bc_DIRA_OWNPV > 0.99)')


# axes.hist(simu_data_full.query(Ds_SELECTION)['Ds_M'], range = (1800, 2200), bins=100, histtype='step', label='simu data with the cut')
axes.set_xlabel('Ds_M')
axes.set_ylabel('Events')
axes.set_title('Ds_M for simu data')
axes.legend(frameon=False)

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.hist(simu_data['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='simu data full')
axes.hist(simu_data.query('(mp_PT > 550) & (mm_PT > 550)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(mp_PT > 550) & (mm_PT > 550)')
axes.hist(simu_data.query('(Jpsi_M < 3150) & (Jpsi_M > 3040)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Jpsi_M < 3150) & (Jpsi_M > 3040)')
axes.hist(simu_data.query('(Jpsi_ENDVERTEX_CHI2 < 9.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Jpsi_ENDVERTEX_CHI2 < 9.)')
# axes.hist(simu_data.query('(pi_PT > 1700.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(pi_PT > 1700.)')
axes.hist(simu_data.query('(pi_TRACK_CHI2NDOF < 3.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(pi_TRACK_CHI2NDOF < 3.)')
axes.hist(simu_data.query('(pi_ProbNNghost < 0.4)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(pi_ProbNNghost < 0.4)')
axes.hist(simu_data.query('(pi_IPCHI2_OWNPV > 9)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(pi_IPCHI2_OWNPV > 9)')
axes.hist(simu_data.query('(Bc_ENDVERTEX_CHI2 < 9.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Bc_ENDVERTEX_CHI2 < 9.)')
axes.hist(simu_data.query('(Bc_IPCHI2_OWNPV < 25.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Bc_IPCHI2_OWNPV < 25.)')
# axes.hist(simu_data.query('(Kp_PT > 1000.) & (Km_PT > 1000.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Kp_PT > 1000.) & (Km_PT > 1000.)')
axes.hist(simu_data.query('(Kp_P > 1000.) & (Km_P > 1000.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Kp_P > 1000.) & (Km_P > 1000.)')
axes.hist(simu_data.query('(pi_P > 1000.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(pi_P > 1000.)')
axes.hist(simu_data.query('(Ds_ENDVERTEX_CHI2 < 16.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Ds_ENDVERTEX_CHI2 < 16.)')
axes.hist(simu_data.query('(Ds_PT > 1000.)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Ds_PT > 1000.)')
axes.hist(simu_data.query('(Bc_FullDTF_M > 1944) & (Bc_FullDTF_M < 1994)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Ds_M > 1944) & (Ds_M < 1994)')
axes.hist(simu_data.query('(Bc_DIRA_OWNPV > 0.99)')['Bc_FullDTF_M'], range = (6250, 6300), bins=100, density = True, histtype='step', label='(Bc_DIRA_OWNPV > 0.99)')


# axes.hist(simu_data_full.query(Ds_SELECTION)['Bc_FullDTF_M'], range = (1800, 2200), density = True, bins=100, density = True, histtype='step', label='simu data with the cut')
axes.set_xlabel('Bc_FullDTF_M')
axes.set_ylabel('Events')
axes.set_title('Bc_FullDTF_M for simu data')
axes.legend(frameon=False)
# Out:
# /afs/cern.ch/user/k/ktrofimi/.venv/lib64/python3.9/site-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.hist(real_data.query(Ds_SELECTION_new)['Ds_M'], range = (1800, 2200), bins=100, histtype='step', label='real data')

# axes.hist(real_data_full.query(Ds_SELECTION)['Ds_M'], range = (1800, 2200), density = True, bins=100, histtype='step', label='real data with the cut')
axes.set_xlabel('Ds_M')
axes.set_ylabel('Events')
axes.set_title('Ds_M for real data')
axes.legend(frameon=False)

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.hist(real_data.query(Ds_SELECTION_new)['Bc_FullDTF_M'], bins=100, range = (6250, 6700), histtype='step', label='real data')

# axes.hist(real_data_full.query(Ds_SELECTION)['Bc_FullDTF_M'], range = (1800, 2200), density = True, bins=100, histtype='step', label='real data with the cut')
axes.set_xlabel('Bc_FullDTF_M')
axes.set_ylabel('Events')
axes.set_title('Bc_FullDTF_M for real data')
axes.legend(frameon=False)

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.hist(real_data.query(Ds_SELECTION_new)['Jpsi_M'], bins=100, histtype='step', label='real data')

# axes.hist(real_data_full.query(Ds_SELECTION)['Jpsi_M'], range = (1800, 2200), density = True, bins=100, histtype='step', label='real data with the cut')
axes.set_xlabel('Jpsi_M')
axes.set_ylabel('Events')
axes.set_title('Jpsi_M for real data')
axes.legend(frameon=False)

# %%
fig, axes = plt.subplots(figsize=(12, 6))

axes.hist(real_data.query(Ds_SELECTION_new)['Bc_FullDTF_M'], range = (6200, 6600), bins=100, histtype='step', label='real data')

# axes.hist(real_data_full.query(Ds_SELECTION)['Bc_FullDTF_M'], range = (1800, 2200), density = True, bins=100, histtype='step', label='real data with the cut')
axes.set_xlabel('Bc_FullDTF_M')
axes.set_ylabel('Events')
axes.set_title('Bc_FullDTF_M for real data')
axes.legend(frameon=False)

# %%
simu_data["min_mm_mp_PT"] = simu_data[["mm_PT", "mp_PT"]].min(axis=1)
simu_data["max_mm_mp_PT"] = simu_data[["mm_PT", "mp_PT"]].max(axis=1)

simu_data["min_K_pi_PT"] = simu_data[["Km_PT", "Kp_PT", "pi_PT"]].min(axis=1)
simu_data["max_K_pi_PT"] = simu_data[["Km_PT", "Kp_PT", "pi_PT"]].max(axis=1)

real_data["min_mm_mp_PT"] = real_data[["mm_PT", "mp_PT"]].min(axis=1)
real_data["max_mm_mp_PT"] = real_data[["mm_PT", "mp_PT"]].max(axis=1)

real_data["min_K_pi_PT"] = real_data[["Km_PT", "Kp_PT", "pi_PT"]].min(axis=1)
real_data["max_K_pi_PT"] = real_data[["Km_PT", "Kp_PT", "pi_PT"]].max(axis=1)

feature_columns = [
 
    'min_mm_mp_PT',
    'max_mm_mp_PT',
    'Bc_ENDVERTEX_CHI2',
    'Bc_IPCHI2_OWNPV',

    'Bc_FD_OWNPV',
    'Jpsi_FD_ORIVX',
    'Ds_FD_ORIVX',
    'min_K_pi_PT'
]

# %%
# Separate features and labels
X_simu = simu_data.query(f"{Ds_SELECTION_new} & (Bc_BKGCAT == 0)")[feature_columns]
y_simu = np.ones(len(simu_data.query(f"{Ds_SELECTION_new} & (Bc_BKGCAT == 0)")))  # Label: 1 for simulation data

X_real = real_data.query(Ds_SELECTION_new)[feature_columns]
y_real = np.zeros(len(real_data.query(Ds_SELECTION_new)))  # Label: 0 for real data

# Combine features and labels
X_all = pd.concat([X_simu, X_real], ignore_index=True)  
y_all = np.concatenate([y_simu, y_real])  


print(f"SIMULATION set size: {X_simu.shape}")
print(f"REAL DATA set size: {X_real.shape}")
print(X_simu)
print(X_real)
# Out:
# SIMULATION set size: (187244, 8)
# REAL DATA set size: (348856, 8)
#         min_mm_mp_PT  max_mm_mp_PT  Bc_ENDVERTEX_CHI2  Bc_IPCHI2_OWNPV  \
# 4        1554.166901   2573.174044           3.875751         0.049280
# 7         859.304362   1138.413962           0.373616         6.438468
# 9        1015.517255   1688.887822           1.909500         1.168681
# 11       2295.810801   5895.807710           1.717635         0.938563
# 13       2050.498217   2799.327759           1.221818         4.749612
# ...              ...           ...                ...              ...
# 547248    824.688207   1659.429827           0.526835         0.246170
# 547249   1405.572826   2886.762309           0.757512         2.431653
# 547250   1160.945183   2178.640475           1.189977         1.073900
# 547254    916.409623   5800.734893           0.494478         0.019628
# 547257   1191.963885   2055.297500           1.120417         5.079989
#
# ...

# %%
#IMPLEMENTING OPTUNA TO FIND THE BEST MODEL another one

X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=76)

print(f"Training set size: {X_train.shape}")
print(f"Test set size: {X_test.shape}")

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 2, 20)
    }
    model_optuna = XGBClassifier(**params, random_state=52, eval_metric="logloss")
    model_optuna.fit(X_train, y_train)
    preds = model_optuna.predict_proba(X_test)[:, 1]
    score = roc_auc_score(y_test, preds)
    if not hasattr(objective, 'best_score') or score > objective.best_score:
        objective.best_score = score
        objective.best_model = model_optuna 
    return score

# Optimize
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=1)
best_model = objective.best_model
joblib.dump(best_model, "best_optuna_model_Ds.pkl")

print("Best parameters:", study.best_params)
print("Best ROC-AUC Score:", study.best_value)
print("Best model saved as 'best_optuna_model_Ds.pkl'")
# Out:
# Training set size: (428880, 8)
# Test set size: (107220, 8)
# [I 2025-03-11 09:00:08,264] A new study created in memory with name: no-name-1b6e4e22-b920-42d6-9283-6d472ba94e85
# [I 2025-03-11 09:07:24,820] Trial 0 finished with value: 0.9565312571653094 and parameters: {'n_estimators': 114, 'learning_rate': 0.013875804535616711, 'max_depth': 19}. Best is trial 0 with value: 0.9565312571653094.
# Best parameters: {'n_estimators': 114, 'learning_rate': 0.013875804535616711, 'max_depth': 19}
# Best ROC-AUC Score: 0.9565312571653094
# Best model saved as 'best_optuna_model_Ds.pkl'

# %%
#TRAINING MODEL WITH K-FOLD AND EARLY STOPPING
from sklearn.preprocessing import LabelEncoder
n_folds = 2
fold_accuracies = []

kf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=11)

# Load Optuna-saved model parameters
with open("best_optuna_model_Ds.pkl", "rb") as file:
    best_model_params = pickle.load(file)
try:
    print(type(best_model_params))  # Debugging step
    print(best_model_params) 
    if isinstance(best_model_params, XGBClassifier):
        best_model_params = best_model_params.get_params()  # Extract parameters from model
    elif not isinstance(best_model_params, dict):
        raise TypeError(f"Unexpected type for best_model_params: {type(best_model_params)}")

    elif not isinstance(best_model_params, dict):
        raise TypeError("Unexpected type for best_model_params:", type(best_model_params))


except ImportError as e:
    print("ImportError occurred:", e)

# Ensure parameters are valid for XGBClassifier
if hasattr(best_model_params, 'get_params'):
    best_model_params = best_model_params.get_params()


best_model_params.update({
    'random_state': 51, 
    'eval_metric': 'logloss' ,
    'early_stopping_rounds': 20 
})

classif_list = []
# Perform k-fold cross-validation
for fold, (train_index, val_index) in enumerate(kf.split(X_all, y_all)):
    print(f"Processing Fold {fold + 1}/{n_folds}...")
    # Initialize the model with the best parameters
    model_es = XGBClassifier(**best_model_params)
    # Split the data using iloc for pandas DataFrame compatibility
    X_train, X_val = X_all.iloc[train_index], X_all.iloc[val_index]
    y_train, y_val = y_all[train_index], y_all[val_index]
    le = LabelEncoder()
    y_train = le.fit_transform(y_train)
    

    # Fit the model with early stopping
    model_es.fit(
        X_train,
        y_train,
        eval_set=[(X_val, y_val)],
        verbose=False
    )
    classif_list.append(model_es)
    # Evaluate the model on the validation set
    y_pred = model_es.predict(X_val)
    acc = accuracy_score(y_val, y_pred)
    fold_accuracies.append(acc)
    print(f"Fold {fold + 1} Accuracy: {acc:.4f}")

mean_accuracy = np.mean(fold_accuracies)
print(f"\nMean Cross-Validation Accuracy: {mean_accuracy:.4f}")

model_es.save_model("best_kfold_early_stopping_model_Ds.json")
# Out:
# <class 'xgboost.sklearn.XGBClassifier'>
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.013875804535616711, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=19, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=114, n_jobs=None,
#               num_parallel_tree=None, random_state=52, ...)
# Processing Fold 1/2...
# ---------------------------------------------------------------------------
# ...

# %%
from xgboost import XGBClassifier

# Load the saved model
model_es = XGBClassifier()
model_es.load_model("best_kfold_early_stopping_model_Ds.json")

# %%
# Predict on the test set
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=76)
y_pred = model_es.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Generate a classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.96
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.97     69605
#          1.0       0.94      0.93      0.94     37615
#
#     accuracy                           0.96    107220
#    macro avg       0.95      0.95      0.95    107220
# weighted avg       0.96      0.96      0.96    107220

# %%
y_prob = model_es.predict_proba(X_test)[:, 1]  # Probabilities for the positive class
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
real_data_predictions = model_es.predict_proba(X_real)[:, 1]
cut = 0.6
real_data_filtered = real_data.query(Ds_SELECTION_new)[real_data_predictions > cut]

#SUPER CORRECT


mass_values = real_data_filtered['Bc_FullDTF_M'].values
mass_values_fit = mass_values[mass_values > 6350]

mass_space_fit = zfit.Space("Bc_FullDTF_M", limits=(6350, 6600))
data_fit = zfit.Data.from_numpy(obs=mass_space_fit, array=mass_values_fit)

lambda_param = zfit.Parameter("lambda", -0.002, -0.005, -0.0001) 
N_bkg = zfit.Parameter("N_bkg", len(mass_values_fit), 0, 1e6)  

exp_pdf = zfit.pdf.Exponential(lambda_param, obs=mass_space_fit)
exp_pdf_extended = exp_pdf.create_extended(N_bkg)

nll = zfit.loss.ExtendedUnbinnedNLL(model=exp_pdf_extended, data=data_fit)
minimizer = zfit.minimize.Minuit()
result = minimizer.minimize(nll)
print(result)

lambda_fit = lambda_param.numpy()
N_bkg_fit = N_bkg.numpy()
print(f"Fitted lambda: {lambda_fit:.6f}")
print(f"Fitted background yield: {N_bkg_fit:.2f}")

nbins = 100
bins = np.linspace(6100, 6600, nbins)
bin_width = (6600 - 6100) / nbins

hist, bin_edges = np.histogram(mass_values, bins=bins)
plt.hist(mass_values, bins=bins, alpha=0.5, label="Data")

x_fit = np.linspace(6100, 6600, 1000)
y_fit = exp_pdf_extended.pdf(x_fit, norm=mass_space_fit).numpy() * N_bkg_fit * bin_width

mask_fit = x_fit >= 6350
mask_extrap = x_fit < 6350

plt.plot(x_fit[mask_fit], y_fit[mask_fit], label="Exponential Fit (Fitted)", color="red")
plt.plot(x_fit[mask_extrap], y_fit[mask_extrap], '--', color="red", label="Extrapolated Fit")

SIGNAL = exp_pdf_extended.ext_integrate(limits=(6250, 6350)).numpy()

S = 400.4*cut
significance = S / np.sqrt(S + SIGNAL)

print(f"background events in a signal region: {SIGNAL}")
print(f"SIGNIFICANCE: {significance}")
print(f"Len of background: {len(mass_values_fit):.2f}")

plt.xlabel("Bc_FullDTF_M [MeV]")
plt.ylabel("Counts")
plt.legend()
plt.title(f"Extended Exponential Fit and Background Estimation")
plt.show()
# Out:
# FitResult of
# <ExtendedUnbinnedNLL model=[<zfit.<class 'zfit.models.basic.Exponential'>  params=[lambda, lambda]] data=[<zfit.Data: Data obs=('Bc_FullDTF_M',) shape=(411, 1)>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═════════╤══════════════════════════════╕
# │  valid  │  converged  │  param at limit  │   edm   │   approx. fmin (full | opt.) │
# ╞═════════╪═════════════╪══════════════════╪═════════╪══════════════════════════════╡
# │  True   │    True     │      False       │ 3.1e-05 │          2268.11 |  9659.096 │
# ╘═════════╧═════════════╧══════════════════╧═════════╧══════════════════════════════╛
#
# Parameters
# name      value  (rounded)    at limit
# ------  ------------------  ----------
# N_bkg              410.975       False
# lambda         -0.00219408       False
# Fitted lambda: -0.002194
# Fitted background yield: 410.97
# background events in a signal region: [238.81866634]
# SIGNIFICANCE: [10.97617363]
# ...

# %%
import vector

filtered_df = real_data_filtered.query(f"{Ds_SELECTION_new} & (Bc_M>6250) & (Bc_M<6300)")

Kp = vector.array(
    {
        "px": filtered_df["Kp_PX"],
        "py": filtered_df["Kp_PY"],
        "pz": filtered_df["Kp_PZ"],
        "E": (filtered_df["Kp_PX"]**2 + filtered_df["Kp_PY"]**2 + filtered_df["Kp_PZ"]**2 + filtered_df["Kp_M"]**2) ** 0.5,
    }
)

Km = vector.array(
    {
        "px": filtered_df["Km_PX"],
        "py": filtered_df["Km_PY"],
        "pz": filtered_df["Km_PZ"],
        "E": (filtered_df["Km_PX"]**2 + filtered_df["Km_PY"]**2 + filtered_df["Km_PZ"]**2 + filtered_df["Km_M"]**2) ** 0.5,
    }
)

KK = Kp + Km

real_data_filtered.loc[
    real_data_filtered.eval(f"{Ds_SELECTION_new} & (Bc_M>6250) & (Bc_M<6300)"),
    "KK_M"
] = KK.mass
filtered_df["KK_M"] = KK.mass
# Out:
# /tmp/ktrofimi/ipykernel_3710919/236625395.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_data_filtered.loc[
# /tmp/ktrofimi/ipykernel_3710919/236625395.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered_df["KK_M"] = KK.mass
# /tmp/ktrofimi/ipykernel_3710919/236625395.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print(len(filtered_df.query("(Bc_M > 6250) & (Bc_M < 6300)")))
print(len(real_data_filtered.query("(KK_M > 1000) & (KK_M < 1040)")))
print(len(filtered_df.query("(KK_M > 1000) & (KK_M < 1040)")))
# Out:
# 406
# 153
# 153

# %%
print(len(real_data_filtered))
# Out:
# 11915

# %%
bdt_thresholds = np.linspace(0.0, 1.0, 100)  
significance_values = []
bdt_efficiencies = []  

max_significance = 0.0
best_threshold = None
best_efficiency = None

train_bdt_scores_simu = classif_list[1].predict_proba(X_simu)[:, 1]  

for threshold in bdt_thresholds:

    real_data_filtered = real_data.query(Ds_SELECTION_new)[real_data_predictions > threshold]
    mass_values = real_data_filtered["Bc_FullDTF_M"].values
    mass_values_fit = mass_values[mass_values > 6350]

    signal_retained = np.sum(train_bdt_scores_simu > threshold)  
    bdt_efficiency = signal_retained / len(X_simu) if len(X_simu) > 0 else 0  
    bdt_efficiencies.append(bdt_efficiency)

    if len(mass_values_fit) == 0:
        significance_values.append(0.0)
        continue

    mass_space_fit = zfit.Space("Bc_FullDTF_M", limits=(6350, 6600))
    data_fit = zfit.Data.from_numpy(obs=mass_space_fit, array=mass_values_fit)

    lambda_param = zfit.Parameter("lambda", -0.002, -0.005, -0.0001) 
    N_bkg = zfit.Parameter("N_bkg", max(len(mass_values_fit), 1), 0, 1e6)  

    exp_pdf = zfit.pdf.Exponential(lambda_param, obs=mass_space_fit)
    exp_pdf_extended = exp_pdf.create_extended(N_bkg)
    nll = zfit.loss.ExtendedUnbinnedNLL(model=exp_pdf_extended, data=data_fit)
    minimizer = zfit.minimize.Minuit()

    try:
        result = minimizer.minimize(nll)
        SIGNAL = float(exp_pdf_extended.ext_integrate(limits=(6250, 6350)).numpy())
    except (zfit.minimizers.strategy.FailMinimizeNaN, RuntimeError):
        SIGNAL = 0.0  

    S = 400.4 * bdt_efficiency  
    significance = S / np.sqrt(S + SIGNAL) if SIGNAL > 0 else 0.0
    significance_values.append(significance)

    if significance > max_significance:
        max_significance = significance
        best_threshold = threshold
        best_efficiency = bdt_efficiency  


print(f"Best threshold: {best_threshold:.3f} with significance: {max_significance:.3f}")
print(f"BDT Efficiency at best threshold: {best_efficiency:.3f}")

plt.plot(bdt_thresholds, significance_values, marker='o', linestyle='-', markersize=2)
plt.xlabel("BDT Threshold ")
plt.ylabel("Significance")
plt.title("Significance vs. BDT Threshold")
plt.grid()
plt.show()
# Out:
# /tmp/ktrofimi/ipykernel_469652/1689785689.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   SIGNAL = float(exp_pdf_extended.ext_integrate(limits=(6250, 6350)).numpy())
# /tmp/ktrofimi/ipykernel_469652/1689785689.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   SIGNAL = float(exp_pdf_extended.ext_integrate(limits=(6250, 6350)).numpy())
# /tmp/ktrofimi/ipykernel_469652/1689785689.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# ...

# %%
plt.plot(bdt_efficiencies, bdt_thresholds, marker='o', linestyle='-', markersize=2)
plt.xlabel("BDT Efficiency (signal) ")
plt.ylabel("bdt_thresholds")
plt.title("bdt_thresholds vs. BDT Efficiency")
plt.grid()
plt.show()

# %%
# Plot feature importance
plot_importance(model_es, importance_type='weight')
plt.title("Feature Importance")
plt.show()

# %%
cut = 0.6
real_data_predictions = classif_list[1].predict_proba(X_real)[:, 1]
real_data_filtered = real_data.query(Ds_SELECTION_new)[real_data_predictions > cut]

print(f"Not-filtered data size: {real_data.query(Ds_SELECTION_new).shape[0]}")
print(f"Filtered data size: {real_data_filtered.shape[0]}")

signal_range = (simu_data.query(f"{Ds_SELECTION_new} & (Bc_BKGCAT == 0)")['Bc_FullDTF_M'] > 6250) & (simu_data.query(f"{Ds_SELECTION_new} & (Bc_BKGCAT == 0)")['Bc_FullDTF_M'] < 6300)
simu_signal_in_range = simu_data.query(f"{Ds_SELECTION_new} & (Bc_BKGCAT == 0)")['Bc_FullDTF_M'][signal_range]

simu_signal_sampled = np.random.choice(simu_signal_in_range, size=15, replace=False)
scaling_factor = 100/len(simu_signal_in_range)

plt.figure(figsize=(8, 6))

# plt.hist(real_data.query(Ds_SELECTION_new)['Bc_FullDTF_M'], range = (5700, 6800), bins=100, alpha=0.7, color='red', label="Original Bc_FullDTF_M Mass (Real Data)", histtype='step')
plt.hist(real_data_filtered['Bc_FullDTF_M'], range = (6200, 6700), bins=100, alpha=0.7, color='green', label="Filtered Bc_FullDTF_M Mass (Real Data)", histtype='step')
# plt.hist(simu_signal_in_range, range = (5700, 6800), bins=100, alpha=0.7, color='purple', label="Simulation Signal (6200-6350 range, 100 events)", histtype='step', weights=(np.ones_like(simu_signal_in_range) * scaling_factor))

plt.xlabel("Bc_FullDTF_M Mass")
plt.ylabel("Events")
plt.title("Bc_FullDTF_M Mass Distribution of Real Data with a BDT cut")
plt.legend()
plt.grid(True)
plt.show()

print(f"signal events: {100*cut}")
# Out:
# Not-filtered data size: 348856
# Filtered data size: 6778
# signal events: 60.0

# %%
#FUNCTION FOR PLOTTING
def plot_model_with_pulls(model, name, data, min, max, scale=1, nbins=50, plot_data=True):
    
    size_normal = len(data)
    lower, upper = data.data_range.limit1d
    x = np.linspace(lower, upper, num=1000)

    # Evaluate model PDF
    y = model.pdf(x) * size_normal / nbins * data.data_range.volume
    y *= scale
    fig = plt.figure(figsize=(8, 6))

    gs = GridSpec(2, 1, height_ratios=[3, 1], hspace=0.05) 

    # Upper subplot: Model and Data with error bars
    ax1 = fig.add_subplot(gs[0])
    ax1.plot(x, y, label="model", color="blue", linewidth=1)
    ax1.set_xlim(min, max)

    if plot_data:
        # Bin the data
        data_binned = data.to_binned(nbins)
        bin_centers = data_binned.axes[0].centers
        bin_widths = data_binned.axes[0].widths
        data_counts = data_binned.values()
        data_uncertainties = np.sqrt(data_counts)  # Poisson errors

        ax1.errorbar(
            bin_centers, data_counts, yerr=data_uncertainties, fmt='o', 
            color='orange', label="data", markersize=1, capsize=1
        )

    ax1.legend()
    ax1.set_ylabel("Counts")
    
    ax1.set_title(name)
    ax1.grid()

    # Lower subplot: Pulls visualization
    ax2 = fig.add_subplot(gs[1], sharex=ax1)
    if plot_data:
        # Compute pulls
        model_at_bins = np.array(model.pdf(bin_centers)) * size_normal / nbins * data.data_range.volume

        pulls = (data_counts - model_at_bins) / data_uncertainties

        ax2.errorbar(
            bin_centers, pulls, yerr=1, fmt='o', 
            color='purple', label="pulls", markersize=1, capsize=1
        )
        ax2.axhline(0, color='black', linestyle='--', linewidth=1)
        ax2.set_ylim(-10, 10) 
        ax2.set_ylabel("Pulls")
        ax2.grid()
        ax2.legend()
    ax2.set_xlabel("Observable")
    plt.tight_layout()
    plt.show()

# %%
print(len(mass_values))
# Out:
# 11942

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(Ds_SELECTION_new)['Bc_FullDTF_M'], range = (6250, 6310), bins=100, density = True, histtype='step', label='simu Bc_FullDTF_M')
ax.set_xlabel('Bc_FullDTF_M')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Bc_FullDTF_M comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#SIGNAL MODEL
from matplotlib.gridspec import GridSpec 
simu_mass = simu_data.query(Ds_SELECTION_new)['Bc_FullDTF_M']
simu_mass_np = simu_mass.to_numpy()
mass_obs = zfit.Space('mass', limits=(6250, 6310))
simu_data_zfit = zfit.data.Data.from_numpy(array=simu_mass_np, obs=mass_obs)

# Parameters
mu_gcb = zfit.Parameter('mu_gcb', 6276.4, 6250, 6310)
sigma_gcb_l = zfit.Parameter('sigma_gcb_l', 4.7, 0.1, 15)
sigma_gcb_r = zfit.Parameter('sigma_gcb_r', 5.4, 0.1, 15)
alpha_gcb_l = zfit.Parameter('alpha_gcb_l', 1.3, 0.1, 30)
n_gcb_l = zfit.Parameter('n_gcb_l', 14.2, 0.1, 20)
alpha_gcb_r = zfit.Parameter('alpha_gcb_r', 1.5, 0.1, 30)
n_gcb_r = zfit.Parameter('n_gcb_r', 7.8, 0.1, 20)

# Signal Yield
n_signal = zfit.Parameter('n_signal', 175341, 0, 1e6)

# Define the PDF (GCB profile)
gcb = zfit.pdf.GeneralizedCB(obs=mass_obs, mu=mu_gcb, sigmal=sigma_gcb_l, 
                             sigmar=sigma_gcb_r, alphal=alpha_gcb_l, 
                             nl=n_gcb_l, alphar=alpha_gcb_r, nr=n_gcb_r)

# Extended model
gcb_extended = gcb.create_extended(n_signal)

# Loss function (Extended Unbinned NLL)
nll_gcb = zfit.loss.ExtendedUnbinnedNLL(model=gcb_extended, data=simu_data_zfit)

# Minimizer
minimizer_minuit = zfit.minimize.Minuit()
result_gcb = minimizer_minuit.minimize(loss=nll_gcb)

# Plot result
plot_model_with_pulls(gcb_extended, "gcb", simu_data_zfit, 6250, 6310, nbins=100)
print(result_gcb)
# Out:
# /tmp/ktrofimi/ipykernel_469652/3942404856.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# FitResult of
# <ExtendedUnbinnedNLL model=[<zfit.<class 'zfit.models.physics.GeneralizedCB'>  params=[alpha_gcb_l, alpha_gcb_r, mu_gcb, n_gcb_l, n_gcb_r, sigma_gcb_l, sigma_gcb_r]] data=[<zfit.Data: Data obs=('mass',) shape=(202227, 1)>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═════════╤══════════════════════════════╕
# │  valid  │  converged  │  param at limit  │   edm   │   approx. fmin (full | opt.) │
# ╞═════════╪═════════════╪══════════════════╪═════════╪══════════════════════════════╡
# │  True   │    True     │      False       │ 2.3e-06 │        651596.71 |  7088.785 │
# ╘═════════╧═════════════╧══════════════════╧═════════╧══════════════════════════════╛
#
# Parameters
# name           value  (rounded)    at limit
# ...

# %%
print(len(simu_data.query(Ds_SELECTION_new)))
# Out:
# 218049

# %%
# CREATING INITIAL MODEL
from matplotlib.gridspec import GridSpec 

simu_mass = simu_data.query(f"{Ds_SELECTION_new} & (Bc_BKGCAT == 0)")['Bc_FullDTF_M']
simu_mass_np = simu_mass.to_numpy()

mass_values = real_data_filtered['Bc_FullDTF_M'].values  
mass_obs = zfit.Space('Bc_FullDTF_M', limits=(6200, 6550))
real_data_zfit = zfit.data.Data.from_numpy(array=mass_values, obs=mass_obs)

mu_gcb = zfit.Parameter('mu_gcb', 6276.4, 6200, 6310, floating=True)
sigma_gcb_l = zfit.Parameter('sigma_gcb_l', 4.7, 0.1, 15, floating=True)
sigma_gcb_r = zfit.Parameter('sigma_gcb_r', 5.4, 0.1, 15, floating=True)
alpha_gcb_l = zfit.Parameter('alpha_gcb_l', 1.3, 0.1, 30, floating=True)
n_gcb_l = zfit.Parameter('n_gcb_l', 14.2, 0.1, 20, floating=True)
alpha_gcb_r = zfit.Parameter('alpha_gcb_r', 1.5, 0.1, 30, floating=True)
n_gcb_r = zfit.Parameter('n_gcb_r', 7.8, 0.1, 20, floating=True)

gcb = zfit.pdf.GeneralizedCB(obs=mass_obs, mu=mu_gcb, sigmal=sigma_gcb_l, sigmar=sigma_gcb_r, 
                        alphal=alpha_gcb_l, nl=n_gcb_l, 
                        alphar=alpha_gcb_r, nr=n_gcb_r)

N_sig = zfit.Parameter("N_sig", 800, 0, 1e6, floating=True)
gcb_extended = gcb.create_extended(N_sig)

lambda_param = zfit.Parameter("lambda", -0.02, -0.04, -0.0001, floating=True)
exp_pdf = zfit.pdf.Exponential(lambda_param, obs=mass_obs)

N_bkg = zfit.Parameter("N_bkg", 11942, 200, 1e6, floating=True)
exp_pdf_extended = exp_pdf.create_extended(N_bkg)

supermodel = zfit.pdf.SumPDF([gcb_extended, exp_pdf_extended])

nll = zfit.loss.ExtendedUnbinnedNLL(model=supermodel, data=real_data_zfit)

minimizer = zfit.minimize.Minuit()
result = minimizer.minimize(loss=nll)

plot_model_with_pulls(supermodel, "GeneralizedCB + Exp Fit", real_data_zfit, 6200, 6550, nbins=80)

print(result)
print(len(mass_values))
# Out:
# /tmp/ktrofimi/ipykernel_469652/3942404856.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# FitResult of
# <ExtendedUnbinnedNLL model=[<zfit.<class 'zfit.models.functor.SumPDF'>  params=[Composed_autoparam_1, Composed_autoparam_2]] data=[<zfit.Data: Data obs=('Bc_FullDTF_M',) shape=(1107, 1)>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═════════╤══════════════════════════════╕
# │  valid  │  converged  │  param at limit  │   edm   │   approx. fmin (full | opt.) │
# ╞═════════╪═════════════╪══════════════════╪═════════╪══════════════════════════════╡
# │  True   │    True     │      False       │ 7.6e-05 │          6019.97 |  132.8055 │
# ╘═════════╧═════════════╧══════════════════╧═════════╧══════════════════════════════╛
#
# Parameters
# name           value  (rounded)    at limit
# -----------  ------------------  ----------
# ...

# %%
#CREATING INITIAL MODEL
from matplotlib.gridspec import GridSpec 

simu_mass = simu_data.query(f"{Ds_SELECTION_new} & (Bc_BKGCAT == 0)")['Bc_FullDTF_M']
simu_mass_np = simu_mass.to_numpy()

mass_values = real_data_filtered['Bc_FullDTF_M'].values  
mass_obs = zfit.Space('Bc_FullDTF_M', limits=(6200, 6550))
simu_data_zfit = zfit.data.Data.from_numpy(array=simu_mass_np, obs=mass_obs)

mu_dcb = zfit.Parameter('mu_dcb', 6276.9, 6259, 6290, floating=False)
sigma_dcb = zfit.Parameter('sigma_dcb', 1.92, 1.1, 19, floating=False)
print(f"Initial sigma_dcb: {sigma_dcb.numpy()}")
alpha_dcb_l = zfit.Parameter('alpha_dcb_l', 4.9, 0.1, 5, floating=False)
n_dcb_l = zfit.Parameter('n_dcb_l', 43.8, 5.1, 50, floating=False)
alpha_dcb_r = zfit.Parameter('alpha_dcb_r', 4.96, 0.1, 5, floating=False)
n_dcb_r = zfit.Parameter('n_dcb_r', 15.7, 7.1, 17, floating=False)

dcb = zfit.pdf.DoubleCB(obs=mass_obs, mu=mu_dcb, sigma=sigma_dcb, 
                        alphal=alpha_dcb_l, nl=n_dcb_l, 
                        alphar=alpha_dcb_r, nr=n_dcb_r)

N_sig = zfit.Parameter("N_sig", 500.06, 0, 1e6, floating=False)
dcb_extended = dcb.create_extended(N_sig)

lambda_param = zfit.Parameter("lambda", -0.01, -0.04, -0.0001, floating=False)
exp_pdf = zfit.pdf.Exponential(lambda_param, obs=mass_obs)

N_bkg = zfit.Parameter("N_bkg", 11942, 200, 1e6, floating=False)
exp_pdf_extended = exp_pdf.create_extended(N_bkg)

supermodel = zfit.pdf.SumPDF([dcb_extended, exp_pdf_extended])

combined_mass = np.concatenate([simu_mass_np, mass_values])  
combined_data = zfit.Data.from_numpy(obs=mass_obs, array=combined_mass)

nll = zfit.loss.UnbinnedNLL(model=supermodel, data=combined_data)

minimizer = zfit.minimize.Minuit()
# result = minimizer.minimize(loss=nll)

plot_model_with_pulls(supermodel, "DoubleCB + Exp Fit", combined_data, 6200, 6550, nbins=100)

# print(result)
print(len(simu_mass)+len(mass_values))
# Out:
# Initial sigma_dcb: 1.92
# /tmp/ktrofimi/ipykernel_1757556/3942404856.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# 163211

# %%
#CREATING FLOATING MODEL
def creating_model ():
    mass_values = real_data_filtered['Bc_FullDTF_M'].values  
    mass_obs = zfit.Space('Bc_FullDTF_M', limits=(6220, 6400))
    simu_data_zfit = zfit.data.Data.from_numpy(array=simu_mass_np, obs=mass_obs)

    shift_mu = zfit.Parameter('shift_mu', 0, -12, 12)
    scale_sigma = zfit.Parameter('scale_sigma', 1., 0.1, 1.9, floating=False)

    mu_base = zfit.Parameter('mu_base', 6276.28, 6259, 6290, floating=False)
    mu = zfit.ComposedParameter('mu', lambda mu, shift: mu + shift, params=[mu_base, shift_mu])

    sigma_base = zfit.Parameter('sigma_base', 1.92, 1.1, 19, floating=False)
    sigma = zfit.ComposedParameter('sigma', lambda sigma, scale: sigma * scale, params=[sigma_base, scale_sigma])

    alpha_dcb_l = zfit.Parameter('alpha_dcb_l', 4.9, 0.1, 5, floating=False)
    n_dcb_l = zfit.Parameter('n_dcb_l', 43.8, 5.1, 50, floating=False)
    alpha_dcb_r = zfit.Parameter('alpha_dcb_r', 4.96, 0.1, 5, floating=False)
    n_dcb_r = zfit.Parameter('n_dcb_r', 15.7, 7.1, 17, floating=False)

    dcb = zfit.pdf.DoubleCB(obs=mass_obs, mu=mu, sigma=sigma, 
                            alphal=alpha_dcb_l, nl=n_dcb_l, 
                            alphar=alpha_dcb_r, nr=n_dcb_r)

    N_sig = zfit.Parameter("N_sig", 500.06, 0, 1e6, floating=True)
    dcb_extended = dcb.create_extended(N_sig)

    lambda_param = zfit.Parameter("lambda", -0.01, -0.04, 0.01, floating=True)
    exp_pdf = zfit.pdf.Exponential(lambda_param, obs=mass_obs)

    N_bkg = zfit.Parameter("N_bkg", 11942, 200, 1e6, floating=True)
    exp_pdf_extended = exp_pdf.create_extended(N_bkg)

    floating_model = zfit.pdf.SumPDF([dcb_extended, exp_pdf_extended])

    combined_mass = np.concatenate([simu_mass_np, mass_values])  
    combined_data = zfit.Data.from_numpy(obs=mass_obs, array=combined_mass)

    # plot_model_with_pulls(floating_model, "DoubleCB + Exp Fit", combined_data, 6220, 6400, nbins=100)

    # print(result)
    # print(len(simu_mass)+len(mass_values))
    return floating_model

# %%
#CREATING FAKE DATASETS
def generate_fake_data(n_samples = 'extended'):
    return supermodel.sample(n=n_samples)

n_experiments=100
datasets = []
for _ in range(n_experiments):
    fake_data = generate_fake_data()
    datasets.append(fake_data)

# %%
#CHEKING Bc_FullDTF_M DISTRIBUTION
i = random.randint(1, 100)
nbins = 45
bins = np.linspace(6200, 6400, nbins)
bin_width = (6400 - 6200) / nbins

hist, bin_edges = np.histogram(mass_values, bins=bins)
plt.hist(datasets[i]['Bc_FullDTF_M'], bins=bins, alpha=0.5, label="Data")
plt.title(f"Bc_FullDTF_M for {i}")
plt.show()

# %%
#DATA TESTING
true_params = {
    "shift_mu": 0.,
    "scale_sigma": 1.,
    "mu_base": 6276.28,
    "sigma_base": 1.92,
    "alpha_dcb_l": 4.9,
    "n_dcb_l": 43.8,
    "alpha_dcb_r": 4.96,
    "n_dcb_r": 15.7,
    "N_sig": 500.06,
    "N_bkg": 11942,
    "lambda": -0.01
}


n = 100 # Number of experiments
fit_results = []
floating_models = []
loss_values = []  # To store loss values
param_values = {}
param_errors = {}

# True parameter values from supermodel (assuming they exist)
# true_params = {param.name: param.numpy() for param in supermodel.get_params()}

# Perform the fits and store results
for i in range(n):
    floating_model = creating_model()
    nll = zfit.loss.ExtendedUnbinnedNLL(model=floating_model, data=datasets[i]['Bc_FullDTF_M'])
    minimizer = zfit.minimize.Minuit()
    result = minimizer.minimize(loss=nll)
    
    fit_results.append(result)
    loss_values.append(result.loss.value())

    # Store parameter values and errors
    if i == 0:  # Initialize storage on first iteration
        param_values = {param.name: [] for param in floating_model.get_params()}
        param_errors = {param.name: [] for param in floating_model.get_params()}

    hesse_errors = result.hesse()
    params = result.params
    for param, values in params.items():
        param_values[param.name].append(values["value"])
        param_errors[param.name].append(hesse_errors[param]["error"])  # Use hesse output


# Calculate pulls
pulls = {
    param: [(param_values[param][i] - true_params[param]) / param_errors[param][i]
            for i in range(n)]
    for param in param_values
}

# Plot parameter distributions
n_params = len(param_values)
n_cols = min(n_params, 4)
n_rows = (n_params + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 3 * n_rows))
axes = axes.flatten()

for i, (param, values) in enumerate(param_values.items()):
    ax = axes[i]
    ax.hist(values, bins=20, alpha=0.7, color='blue')
    ax.axvline(np.mean(values), color='red', linestyle='dashed', label='Mean')
    ax.set_title(param)
    ax.legend()

plt.tight_layout()
plt.show()

# Plot Pull Distributions
fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 3 * n_rows))
axes = axes.flatten()

for i, (param, values) in enumerate(pulls.items()):
    ax = axes[i]
    ax.hist(values, bins=20, alpha=0.7, color='green')
    ax.axvline(np.mean(values), color='red', linestyle='dashed', label='Mean Pull')
    ax.set_title(f"Pull Distribution: {param}")
    ax.legend()

plt.tight_layout()
plt.show()

# Plot Loss Values
# Normalize loss values (if necessary)
loss_mean = np.mean(loss_values)
loss_std = np.std(loss_values)
loss_pulls = [(l - loss_mean) / loss_std for l in loss_values]  # Standardized

# Plot Normalized Loss Distribution
plt.figure(figsize=(8, 6))
plt.hist(loss_pulls, bins=20, alpha=0.7, color='purple', density=True)

# Overlay a standard Gaussian for reference
x = np.linspace(-3, 3, 100)
plt.plot(x, np.exp(-x**2 / 2) / np.sqrt(2 * np.pi), color="red", linestyle="dashed", label="N(0,1) Gaussian")

plt.axvline(0, color='black', linestyle='--', linewidth=1)
plt.xlabel("Normalized Loss Value (Pulls)")
plt.ylabel("Density")
plt.title("Standardized Loss Value Distribution")
plt.legend()
plt.grid()
plt.show()

# %%
mass_values = real_data_filtered['Bc_FullDTF_M'].values  
mass_obs = zfit.Space('Bc_FullDTF_M', limits=(6200, 6700))
simu_data_zfit = zfit.data.Data.from_numpy(array=simu_mass_np, obs=mass_obs)

shift_mu = zfit.Parameter('shift_mu', 0, -12, 12)
scale_sigma = zfit.Parameter('scale_sigma', 1., 0.1, 1.9, floating=False)

mu_base = zfit.Parameter('mu_base', 6276.28, 6259, 6290, floating=False)
mu = zfit.ComposedParameter('mu', lambda mu, shift: mu + shift, params=[mu_base, shift_mu])

sigma_base = zfit.Parameter('sigma_base', 1.92, 1.1, 19, floating=False)
sigma = zfit.ComposedParameter('sigma', lambda sigma, scale: sigma * scale, params=[sigma_base, scale_sigma])

alpha_dcb_l = zfit.Parameter('alpha_dcb_l', 4.9, 0.1, 5, floating=False)
n_dcb_l = zfit.Parameter('n_dcb_l', 43.8, 5.1, 50, floating=False)
alpha_dcb_r = zfit.Parameter('alpha_dcb_r', 4.96, 0.1, 5, floating=False)
n_dcb_r = zfit.Parameter('n_dcb_r', 15.7, 7.1, 17, floating=False)

dcb = zfit.pdf.DoubleCB(obs=mass_obs, mu=mu, sigma=sigma, 
                        alphal=alpha_dcb_l, nl=n_dcb_l, 
                        alphar=alpha_dcb_r, nr=n_dcb_r)

N_sig = zfit.Parameter("N_sig", 890.06, 0, 1e6, floating=True)
dcb_extended = dcb.create_extended(N_sig)

lambda_param = zfit.Parameter("lambda", -0.002, -0.04, 0.01, floating=True)
exp_pdf = zfit.pdf.Exponential(lambda_param, obs=mass_obs)

N_bkg = zfit.Parameter("N_bkg", 11942, 200, 1e6, floating=True)
exp_pdf_extended = exp_pdf.create_extended(N_bkg)

floating_model = zfit.pdf.SumPDF([dcb_extended, exp_pdf_extended])

combined_mass = np.concatenate([simu_mass_np, mass_values])  
combined_data = zfit.Data.from_numpy(obs=mass_obs, array=combined_mass)

real_data_zfit = zfit.data.Data.from_numpy(array=mass_values, obs=mass_obs)
plot_model_with_pulls(floating_model, "DoubleCB + Exp Fit", real_data_zfit, 6200, 6700, nbins=100)

print(result)
# print(len(simu_mass)+len(mass_values))
# Out:
# /tmp/ktrofimi/ipykernel_2371375/1815706554.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# FitResult of
# <ExtendedUnbinnedNLL model=[<zfit.<class 'zfit.models.functor.SumPDF'>  params=[Composed_autoparam_337, Composed_autoparam_338]] data=[<zfit.Data: Data obs=('Bc_FullDTF_M',) shape=(12433, 1)>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═══════╤══════════════════════════════╕
# │  valid  │  converged  │  param at limit  │  edm  │   approx. fmin (full | opt.) │
# ╞═════════╪═════════════╪══════════════════╪═══════╪══════════════════════════════╡
# │  True   │    True     │      False       │ 6e-07 │         64049.51 |  8669.846 │
# ╘═════════╧═════════════╧══════════════════╧═══════╧══════════════════════════════╛
#
# Parameters
# name        value  (rounded)        hesse    at limit
# ...

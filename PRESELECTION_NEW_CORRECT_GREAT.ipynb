# %%
Ds_SELECTION = (
    # table 13
    "(Ds_ENDVERTEX_CHI2 < 16.) &"
    "(Ds_PT > 1000.) &"
    "(Ds_M > 1943) & (Ds_M < 1993) &"
    "(Bc_ENDVERTEX_CHI2 < 9.) & "
    "(Bc_IPCHI2_OWNPV < 25.) & "
    "(Bc_DIRA_OWNPV > 0.99) &"
    "((Kp_IPCHI2_OWNPV + Km_IPCHI2_OWNPV + pi_IPCHI2_OWNPV) > 9) & "
    # table 6
    "(mp_isMuon == 1) & (mm_isMuon == 1) &"
    "(mp_TRACK_CHI2NDOF < 3) & (mm_TRACK_CHI2NDOF < 3) &"
    # "(mp_RichDLLpi > 0) & (mm_RichDLLpi > 0) &"
    "(mp_PT > 550) & (mm_PT > 550) &"

    "(Jpsi_M > 3040) & (Jpsi_M < 3140) &"
    "(Jpsi_ENDVERTEX_CHI2 < 9) &"

    # "(pi_PT > 1000) &"
    # "(pi_TRACK_CHI2NDOF < 3) &"
    # "(pi_TRACK_GhostProb < 0.4) &"
    # "(pi_IPCHI2_OWNPV > 9) &"

    "(Bc_ENDVERTEX_CHI2 < 9) &"
    "(Bc_IPCHI2_OWNPV < 25) &"

    # # table 7
    # "(mp_PT > 500) & (mm_PT > 500) &"
    # "(Jpsi_M > 3010) & (Jpsi_M < 3170) &"
    # "(Jpsi_ENDVERTEX_CHI2 < 16) &"
    # "(Bc_ENDVERTEX_CHI2 < 10) &"
    # # "(Bc_M > 5200) & (Bc_M < 5550) &"

    # # table 8
    # "(Kp_TRACK_CHI2NDOF < 3.) & (Km_TRACK_CHI2NDOF < 3.) & (pi_TRACK_CHI2NDOF < 3.) & "
    # "(Kp_PT > 100.) & (Km_PT > 100.) & (pi_PT > 100.) & "
    # "(Kp_P > 1000.) & (Km_P > 1000.) & (pi_P > 1000.) & "
    # "(Kp_MINIPCHI2 > 4) & (Km_MINIPCHI2 > 4) & (pi_MINIPCHI2 > 4) & "
    # "((Kp_PT + Km_PT + pi_PT) > 1800.) & "
    # "(Ds_ENDVERTEX_CHI2 < 10) &"
    # "(Ds_DIRA_OWNPV > 0) &"
    # # "(Kp_RichDLLpi > -10) & (Km_RichDLLpi > -10) & "
    # # "(pi_RichDLLpi < 20) &"
    # "(Ds_M > 1943.49) & (Ds_M < 1993.49) &"
    # "(Bc_PT > 5000) &"
    # # "(Bc_M > 5300) & (Bc_M < 5950) &"
    # "(Bc_ENDVERTEX_CHI2 < 10) &"

    # table 9
    "(mp_TRACK_CHI2NDOF < 3) & (mm_TRACK_CHI2NDOF < 3) &"
    "(mp_isMuon == 1) & (mm_isMuon == 1) &"
    # "(mp_RichDLLpi > 0) & (mm_RichDLLpi > 0) &"
    "(mp_PT > 550) & (mm_PT > 550) &"
    "(mp_IPCHI2_OWNPV > 4) & (mm_IPCHI2_OWNPV > 4) &"
    "(Jpsi_M > 3040) & (Jpsi_M < 3140) &"
    "(Jpsi_ENDVERTEX_CHI2 < 9) &"

    # table 10
    "(pi_TRACK_CHI2NDOF < 3) &"
    "(pi_TRACK_GhostProb < 0.4) &"
    "(pi_PT > 200) &"
    "(pi_ProbNNpi > 0.2) &"
    "(pi_ProbNNk < 0.5) &"
    "(Kp_TRACK_CHI2NDOF < 3.) & (Km_TRACK_CHI2NDOF < 3.) &"
    "(Kp_TRACK_GhostProb < 0.4) & (Km_TRACK_GhostProb < 0.4) &"
    "(Kp_PT > 200) & (Km_PT > 200) &"
    "(Kp_ProbNNk > 0.1) & (Km_ProbNNk > 0.1) "



    # "(Kp_PT > 900) & (Km_PT > 900) & (pi_PT > 900)"

)

Ds_SELECTION_original = (
    # table 13
    "(Ds_ENDVERTEX_CHI2 < 16.) &"
    "(Ds_PT > 1000.) &"
    "(Ds_M > 1943) & (Ds_M < 1993) &"
    "(Bc_ENDVERTEX_CHI2 < 9.) & "
    "(Bc_IPCHI2_OWNPV < 25.) & "
    "(Bc_DIRA_OWNPV > 0.99) &"
    "((Kp_IPCHI2_OWNPV + Km_IPCHI2_OWNPV + pi_IPCHI2_OWNPV) > 9) & "
    # table 6
    "(mp_isMuon == 1) & (mm_isMuon == 1) &"
    "(mp_TRACK_CHI2NDOF < 3) & (mm_TRACK_CHI2NDOF < 3) &"
    "(mp_RichDLLpi > 0) & (mm_RichDLLpi > 0) &"
    "(mp_PT > 550) & (mm_PT > 550) &"

    "(Jpsi_M > 3040) & (Jpsi_M < 3140) &"
    "(Jpsi_ENDVERTEX_CHI2 < 9) &"

    "(pi_PT > 1000) &"
    "(pi_TRACK_CHI2NDOF < 3) &"
    "(pi_TRACK_GhostProb < 0.4) &"
    "(pi_IPCHI2_OWNPV > 9) &"

    "(Bc_ENDVERTEX_CHI2 < 9) &"
    "(Bc_IPCHI2_OWNPV < 25) &"

    # table 7
    "(mp_PT > 500) & (mm_PT > 500) &"
    "(Jpsi_M > 3010) & (Jpsi_M < 3170) &"
    "(Jpsi_ENDVERTEX_CHI2 < 16) &"
    "(Bc_ENDVERTEX_CHI2 < 10) &"
    # "(Bc_M > 5200) & (Bc_M < 5550) &"

    # table 8
    "(Kp_TRACK_CHI2NDOF < 3.) & (Km_TRACK_CHI2NDOF < 3.) & (pi_TRACK_CHI2NDOF < 3.) & "
    "(Kp_PT > 100.) & (Km_PT > 100.) & (pi_PT > 100.) & "
    "(Kp_P > 1000.) & (Km_P > 1000.) & (pi_P > 1000.) & "
    "(Kp_MINIPCHI2 > 4) & (Km_MINIPCHI2 > 4) & (pi_MINIPCHI2 > 4) & "
    "((Kp_PT + Km_PT + pi_PT) > 1800.) & "
    "(Ds_ENDVERTEX_CHI2 < 10) &"
    "(Ds_DIRA_OWNPV > 0) &"
    "(Kp_RichDLLpi > -10) & (Km_RichDLLpi > -10) & "
    "(pi_RichDLLpi < 20) &"
    "(Ds_M > 1943.49) & (Ds_M < 1993.49) &"
    "(Bc_PT > 5000) &"
    # "(Bc_M > 5300) & (Bc_M < 5950) &"
    "(Bc_ENDVERTEX_CHI2 < 10) &"

    # table 9
    "(mp_TRACK_CHI2NDOF < 3) & (mm_TRACK_CHI2NDOF < 3) &"
    "(mp_isMuon == 1) & (mm_isMuon == 1) &"
    "(mp_RichDLLpi > 0) & (mm_RichDLLpi > 0) &"
    "(mp_PT > 550) & (mm_PT > 550) &"
    "(mp_IPCHI2_OWNPV > 4) & (mm_IPCHI2_OWNPV > 4) &"
    "(Jpsi_M > 3040) & (Jpsi_M < 3140) &"
    "(Jpsi_ENDVERTEX_CHI2 < 9) &"

    # table 10
    "(pi_TRACK_CHI2NDOF < 3) &"
    "(pi_TRACK_GhostProb < 0.4) &"
    "(pi_PT > 200) &"
    "(pi_ProbNNpi > 0.2) &"
    "(pi_ProbNNk < 0.5) &"
    "(Kp_TRACK_CHI2NDOF < 3.) & (Km_TRACK_CHI2NDOF < 3.) &"
    "(Kp_TRACK_GhostProb < 0.4) & (Km_TRACK_GhostProb < 0.4) &"
    "(Kp_PT > 200) & (Km_PT > 200) &"
    "(Kp_ProbNNk > 0.1) & (Km_ProbNNk > 0.1)"


)

# %%
#IMPORTING LIBRARIES
import uproot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import mean
from numpy import std

# %%
#LOADING DATASET

# files_real_data = [
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2011_MagDown.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2011_MagUp.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2012_MagDown.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2012_MagUp.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2015_MagDown.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2015_MagUp.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2016_MagDown.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2016_MagUp.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2017_MagDown.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2017_MagUp.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2018_MagDown.root',
#     '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2018_MagUp.root',
# ]
files_simu_data = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2011_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2012_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2015_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2016_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2017_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2018_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2018_MagUp.root',
]
# real_data = uproot.concatenate(files_real_data, library='pd')
simu_data = uproot.concatenate(files_simu_data, library='pd')

# %%
files_real_data_Down = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2018_MagDown.root',
]
files_real_data_Up = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2018_MagDown.root',
]
files_real_data_1 = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2011_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2012_MagUp.root',
]

files_real_data_2 = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2015_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2016_MagUp.root',
]

files_real_data_3 = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2017_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2018_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data_new/KKpi/2018_MagUp.root',
]

# %%
files_simu_data_Down = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2018_MagDown.root',
]
files_simu_data_Up = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2018_MagDown.root',
]
files_simu_data_1 = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2011_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2012_MagUp.root',
]

files_simu_data_2 = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2015_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2016_MagUp.root',
]

files_simu_data_3 = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2017_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2018_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDs_KKpi/2018_MagUp.root',
]

# %%
simu_data_Down = uproot.concatenate(files_simu_data_Down, library='pd')
simu_data_Up = uproot.concatenate(files_simu_data_Up, library='pd')
simu_data_1 = uproot.concatenate(files_simu_data_1, library='pd')
simu_data_2 = uproot.concatenate(files_simu_data_2, library='pd')
simu_data_3 = uproot.concatenate(files_simu_data_3, library='pd')

# %%
print(len(simu_data_Down))
print(len(simu_data_Up))
print(len(simu_data_1))
print(len(simu_data_2))
print(len(simu_data_3))
# Out:
# 278792
# 278792
# 214860
# 165269
# 167129

# %%
real_data_Down = uproot.concatenate(files_real_data_Down, library='pd')
real_data_Up = uproot.concatenate(files_real_data_Up, library='pd')
real_data_1 = uproot.concatenate(files_real_data_1, library='pd')
real_data_2 = uproot.concatenate(files_real_data_2, library='pd')
real_data_3 = uproot.concatenate(files_real_data_3, library='pd')

# %%
print(len(real_data_Down))
print(len(real_data_Up))
print(len(real_data_1))
print(len(real_data_2))
print(len(real_data_3))
# Out:
# 219811
# 219811
# 114677
# 120078
# 193722

# %%
print(len(simu_data.query(f"{Ds_SELECTION} & ((Km_M + Kp_M) > 1000) & ((Km_M + Kp_M) < 1040) & (Bc_BKGCAT == 0)")))
print(len(simu_data.query("((Km_M + Kp_M) > 1000) & ((Km_M + Kp_M) < 1040) & (Bc_BKGCAT == 0)")))
print(len(simu_data.query("(Bc_BKGCAT == 0)")))
print(len(simu_data.query("((Km_M + Kp_M) > 1000) & ((Km_M + Kp_M) < 1040)")))
# Out:
# 0
# 0
# 262242
# 0

# %%
import vector

Kp = vector.array(
    {
        "px": simu_data["Kp_PX"],
        "py": simu_data["Kp_PY"],
        "pz": simu_data["Kp_PZ"],
        "E": (simu_data["Kp_PX"]**2 + simu_data["Kp_PY"]**2 + simu_data["Kp_PZ"]**2 + simu_data["Kp_M"]**2) ** 0.5,
    }
)

Km = vector.array(
    {
        "px": simu_data["Km_PX"],
        "py": simu_data["Km_PY"],
        "pz": simu_data["Km_PZ"],
        "E": (simu_data["Km_PX"]**2 + simu_data["Km_PY"]**2 + simu_data["Km_PZ"]**2 + simu_data["Km_M"]**2) ** 0.5,
    }
)


KK = Kp + Km

simu_data["KK_M"] = KK.mass

# %%
print(len(simu_data.query(f"{Ds_SELECTION} & (KK_M > 1000) & (KK_M < 1040) & (Bc_BKGCAT == 0)")))
print(len(simu_data.query("(KK_M > 1000) & (KK_M < 1040) & (Bc_BKGCAT == 0)")))
print(len(simu_data.query("(Bc_BKGCAT == 0)")))
print(len(simu_data.query("(KK_M > 1000) & (KK_M < 1040)")))
# Out:
# 85939
# 121018
# 262242
# 169345

# %%
print(len(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")))
# Out:
# 187244

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query("Bc_BKGCAT == 0")['Bc_FullDTF_M'], bins=80, density = True, range = (6225,6325), histtype='step', label='simu Bc_FullDTF_M')
ax.hist(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")['Bc_FullDTF_M'], bins=80, density = True, range = (6225,6325), histtype='step', label='simu with cut Bc_FullDTF_M')

ax.set_xlabel('Bc_FullDTF_M')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Bc_FullDTF_M comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query("Bc_BKGCAT == 0")['Km_PT'], range = (200, 500), bins=80, density = True, histtype='step', label='simu Km_PT')
ax.hist(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")['Km_PT'], range = (200, 500), bins=80, density = True, histtype='step', label='simu with cut Km_PT')
ax.hist(real_data['Km_PT'], range = (200, 500), bins=80, density = True, histtype='step', label='real Km_PT')
ax.hist(real_data.query(Ds_SELECTION)['Km_PT'], range = (200, 500), bins=80, density = True, histtype='step', label='real with cut Km_PT')
ax.set_xlabel('Km_PT')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Km_PT comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()
# Out:
# /afs/cern.ch/user/k/ktrofimi/.venv/lib64/python3.9/site-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /afs/cern.ch/user/k/ktrofimi/.venv/lib64/python3.9/site-packages/numpy/lib/_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query("Bc_BKGCAT == 0")['Kp_PT'], range = (200, 10000), bins=80, density = True, histtype='step', label='simu Kp_PT')
ax.hist(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")['Kp_PT'], range = (200, 10000), bins=80, density = True, histtype='step', label='simu with cut Kp_PT')
ax.hist(real_data['Kp_PT'], range = (200, 10000), bins=80, density = True, histtype='step', label='real Kp_PT')
ax.hist(real_data.query(Ds_SELECTION)['Kp_PT'], range = (200, 10000), bins=80, density = True, histtype='step', label='real with cut Kp_PT')

ax.set_xlabel('Kp_PT')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Kp_PT comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query("Bc_BKGCAT == 0")['pi_PT'], range = (200, 10000), bins=80, density = True, histtype='step', label='simu pi_PT')
ax.hist(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")['pi_PT'], range = (200, 10000), bins=80, density = True, histtype='step', label='simu with cut pi_PT')
ax.hist(real_data['pi_PT'], range = (200, 10000), bins=80, density = True, histtype='step', label='real pi_PT')
ax.hist(real_data.query(Ds_SELECTION)['pi_PT'], range = (200, 10000), bins=80, density = True, histtype='step', label='real with cut pi_PT')
ax.set_xlabel('pi_PT')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('pi_PT comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query("Bc_BKGCAT == 0")['Kp_IPCHI2_OWNPV'], range = (200, 10000), bins=80, density = True, histtype='step', label='simu Kp_IPCHI2_OWNPV')
ax.hist(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")['Kp_IPCHI2_OWNPV'], range = (200, 10000), bins=80, density = True, histtype='step', label='simu with cut Kp_IPCHI2_OWNPV')
ax.hist(real_data['Kp_IPCHI2_OWNPV'], range = (200, 10000), bins=80, density = True, histtype='step', label='real Kp_IPCHI2_OWNPV')
ax.hist(real_data.query(Ds_SELECTION)['Kp_IPCHI2_OWNPV'], range = (200, 10000), bins=80, density = True, histtype='step', label='real with cut Kp_IPCHI2_OWNPV')

ax.set_xlabel('Kp_IPCHI2_OWNPV')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Kp_IPCHI2_OWNPV comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query("Bc_BKGCAT == 0")['Km_IPCHI2_OWNPV'], range = (1, 12), bins=80, density = True, histtype='step', label='simu Km_IPCHI2_OWNPV')
ax.hist(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")['Km_IPCHI2_OWNPV'], range = (1, 12), bins=80, density = True, histtype='step', label='simu with cut Km_IPCHI2_OWNPV')
ax.hist(real_data['Km_IPCHI2_OWNPV'], range = (1, 12), bins=80, density = True, histtype='step', label='real Km_IPCHI2_OWNPV')
ax.hist(real_data.query(Ds_SELECTION)['Km_IPCHI2_OWNPV'], range = (1, 12), bins=80, density = True, histtype='step', label='real with cut Km_IPCHI2_OWNPV')

ax.set_xlabel('Km_IPCHI2_OWNPV')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Km_IPCHI2_OWNPV comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query("Bc_BKGCAT == 0")['pi_IPCHI2_OWNPV'], range = (200, 10000), bins=80, density = True, histtype='step', label='simu pi_IPCHI2_OWNPV')
ax.hist(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")['pi_IPCHI2_OWNPV'], range = (200, 10000), bins=80, density = True, histtype='step', label='simu with cut pi_IPCHI2_OWNPV')
ax.hist(real_data['pi_IPCHI2_OWNPV'], range = (200, 10000), bins=80, density = True, histtype='step', label='real pi_IPCHI2_OWNPV')
ax.hist(real_data.query(Ds_SELECTION)['pi_IPCHI2_OWNPV'], range = (200, 10000), bins=80, density = True, histtype='step', label='real with cut pi_IPCHI2_OWNPV')

ax.set_xlabel('pi_IPCHI2_OWNPV')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('pi_IPCHI2_OWNPV comparison')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
print(len(simu_data.query(f"{Ds_SELECTION} & (Bc_BKGCAT == 0)")))
# Out:
# 187244

# %%
#FOR PREVIOUS DATA
from uncertainties import ufloat


R = ufloat(0.683e-2, 0.018e-2)
BR_B_KJpsi = ufloat(1.02e-3, 0.019e-3)
fc_fu=ufloat(7.26e-3, 0.08e-3)
BR_Bc_JpsiDs_Bc_Jpsipi = ufloat(5.33, 0.96)
Vcd = ufloat(0.218, 0.004)
Vcs = ufloat(0.997, 0.017)
BR_Jpsi_mumu = ufloat(5.84e-2, 0.06e-2)

BR_D_D0pi = ufloat(67.7e-2, 0.5e-2)
BR_D0_Kpi = ufloat(3.9e-2, 0.09e-2)

BR_Ds_KKpi = ufloat(5.4e-2, 0)

N_mc_norm_sel = 2360305
N_mc_norm_gen = 15000000
N_mc_sig_sel = 25728
N_mc_sig_gen = 2200000

N_norm = 2698130

eps_acc = ufloat(17.3e-2, 0)  # If no uncertainty is given


#calculating branch ratio
BR_Bc_Jpsipi = (R*BR_B_KJpsi)/fc_fu
BR_Bc_JpsiDs = BR_Bc_JpsiDs_Bc_Jpsipi*BR_Bc_Jpsipi

BR_Bc_JpsiD = BR_Bc_JpsiDs * ((Vcd/Vcs)**2)

#calculating number of signal events
eps_norm = (N_mc_norm_sel/N_mc_norm_gen)*eps_acc
eps_sig = (N_mc_sig_sel/N_mc_sig_gen)*eps_acc

BR_B_KJpsi_mumu = BR_B_KJpsi*BR_Jpsi_mumu

super_br = BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu

N_sig = 1.5*((BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu*N_norm*eps_sig)/(BR_B_KJpsi_mumu*eps_norm))*fc_fu


BR_Bc_JpsiDs_kkpi = BR_Jpsi_mumu*BR_Ds_KKpi*(BR_Bc_JpsiDs/2)


eps_fabian = (1135*BR_B_KJpsi_mumu*eps_norm)/(1.5*BR_Bc_JpsiDs_kkpi*N_norm*fc_fu)


print(f"BR_Bc_JpsiDs_kkpi: {BR_Bc_JpsiDs_kkpi}")
print(f"eps_fabian: {eps_fabian}")
print('-----------------------------')
print(f"BR_Bc_Jpsipi: {BR_Bc_Jpsipi}") 
print(f"BR_Bc_JpsiDs: {BR_Bc_JpsiDs}") 
print(f"BR_Bc_JpsiD: {BR_Bc_JpsiD}") 
print("--------------------------")
print(f"super_br: {super_br}") 
print("--------------------------")
print(f"eps_norm: {eps_norm}")
print(f"eps_sig: {eps_sig}")
print(f"BR_B_KJpsi_mumu: {BR_B_KJpsi_mumu}")
print(f"N_sig: {N_sig}")

BR_Jpsi_mumu = ufloat(5.84e-2, 0.06e-2)

N_mc_norm_sel = 2360305
N_mc_norm_gen = 15000000
N_mc_sig_sel = 38627
N_mc_sig_gen = 2200000

N_norm = 2698130

eps_acc = 17.3e-2

eps_norm = (N_mc_norm_sel/N_mc_norm_gen)*eps_acc
eps_sig = (N_mc_sig_sel/N_mc_sig_gen)*eps_acc

BR_B_KJpsi_mumu = BR_B_KJpsi*BR_Jpsi_mumu

N_sig = ((BR_Bc_JpsiD*N_norm*eps_sig)/(BR_B_KJpsi*BR_Jpsi_mumu*eps_norm))*fc_fu

print(f"eps_norm: {eps_norm}")
print(f"eps_sig: {eps_sig}")
print(f"BR_B_KJpsi_mumu: {BR_B_KJpsi_mumu}")
print(f"N_sig: {N_sig}")
# Out:
# BR_Bc_JpsiDs_kkpi: (8.1+/-1.5)e-06
# eps_fabian: 0.0078+/-0.0014
# -----------------------------
# BR_Bc_Jpsipi: 0.000960+/-0.000033
# BR_Bc_JpsiDs: 0.0051+/-0.0009
# BR_Bc_JpsiD: 0.00024+/-0.00005
# --------------------------
# super_br: (3.8+/-0.7)e-07
# --------------------------
# eps_norm: 0.027222184333333333+/-0
# eps_sig: 0.0020231563636363636+/-0
# BR_B_KJpsi_mumu: (5.96+/-0.13)e-05
# N_sig: 13.8+/-2.6
# eps_norm: 0.027222184333333333
# eps_sig: 0.003037486818181818
# BR_B_KJpsi_mumu: (5.96+/-0.13)e-05
# N_sig: (9.0+/-1.7)e+03

# %%
#FOR THE NEW DATA
#FOR PREVIOUS DATA

R = ufloat(0.683e-2, 0.018e-2)
BR_B_KJpsi = ufloat(1.02e-3, 0.019e-3)
fc_fu=ufloat(7.26e-3, 0.08e-3)
BR_Bc_JpsiDst_Bc_Jpsipi = ufloat(5.33, 0.96)
Vcd = ufloat(0.218, 0.004)
Vcs = ufloat(0.997, 0.017)
BR_Jpsi_mumu = ufloat(5.84e-2, 0.06e-2)

BR_D_D0pi = ufloat(67.7e-2, 0.5e-2)
BR_D0_Kpi = ufloat(3.9e-2, 0.09e-2)

BR_Ds_KKpi = ufloat(5.4e-2, 0)

N_mc_norm_sel = 2360305
N_mc_norm_gen = 15000000
#-----
N_mc_sig_sel = 38627
N_mc_sig_gen = 2200000
#-----
N_norm = 2698130

eps_acc = ufloat(17.3e-2, 0)  # If no uncertainty is given


#calculating branch ratio
BR_Bc_Jpsipi = (R*BR_B_KJpsi)/fc_fu
BR_Bc_JpsiDst = BR_Bc_JpsiDst_Bc_Jpsipi*BR_Bc_Jpsipi

BR_Bc_JpsiD = BR_Bc_JpsiDst * ((Vcd/Vcs)**2)

#calculating number of signal events
eps_norm = (N_mc_norm_sel/N_mc_norm_gen)*eps_acc
eps_sig = (N_mc_sig_sel/N_mc_sig_gen)*eps_acc

BR_B_KJpsi_mumu = BR_B_KJpsi*BR_Jpsi_mumu

super_br = BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu

N_sig = 1.5*((BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu*N_norm*eps_sig)/(BR_B_KJpsi_mumu*eps_norm))*fc_fu


BR_Bc_JpsiDs_kkpi = BR_Jpsi_mumu*BR_Ds_KKpi*(BR_Bc_JpsiDst/2)


eps_fabian = (1135*BR_B_KJpsi_mumu*eps_norm)/(1.5*BR_Bc_JpsiDs_kkpi*N_norm*fc_fu)


print(f"BR_Bc_JpsiDs_kkpi: {BR_Bc_JpsiDs_kkpi}")
print(f"eps_fabian: {eps_fabian}")
print('-----------------------------')
print(f"BR_Bc_Jpsipi: {BR_Bc_Jpsipi}") 
print(f"BR_Bc_JpsiDst: {BR_Bc_JpsiDst}") 
print(f"BR_Bc_JpsiD: {BR_Bc_JpsiD}") 
print("--------------------------")
print(f"super_br: {super_br}") 
print("--------------------------")
print(f"eps_norm: {eps_norm}")
print(f"eps_sig: {eps_sig}")
print(f"BR_B_KJpsi_mumu: {BR_B_KJpsi_mumu}")
print(f"N_sig: {N_sig}")

#FOR THE NEW DATA
# Out:
# BR_Bc_JpsiDs_kkpi: (8.1+/-1.5)e-06
# eps_fabian: 0.0078+/-0.0014
# -----------------------------
# BR_Bc_Jpsipi: 0.000960+/-0.000033
# BR_Bc_JpsiDst: 0.0051+/-0.0009
# BR_Bc_JpsiD: 0.00024+/-0.00005
# --------------------------
# super_br: (3.8+/-0.7)e-07
# --------------------------
# eps_norm: 0.027222184333333333+/-0
# eps_sig: 0.003037486818181818+/-0
# BR_B_KJpsi_mumu: (5.96+/-0.13)e-05
# N_sig: 21+/-4

# %%
#FOR NEW NORMALISATION CHANNEL: Ds
#FOR PREVIOUS DATA

R = ufloat(0.683e-2, 0.018e-2)
BR_B_KJpsi = ufloat(1.02e-3, 0.019e-3)
fc_fu=ufloat(7.26e-3, 0.08e-3)
BR_Bc_JpsiDst_Bc_Jpsipi = ufloat(5.33, 0.96)
Vcd = ufloat(0.218, 0.004)
Vcs = ufloat(0.997, 0.017)
BR_Jpsi_mumu = ufloat(5.84e-2, 0.06e-2)

BR_D_D0pi = ufloat(67.7e-2, 0.5e-2)
BR_D0_Kpi = ufloat(3.9e-2, 0.09e-2)

BR_Ds_KKpi = ufloat(5.4e-2, 0)

# N_mc_norm_sel_new = 237253
N_mc_norm_sel_new = 179956
N_mc_norm_gen_new = 6200000
#-----
N_mc_norm_sel = 2360305
N_mc_norm_gen = 15000000
#-----
N_mc_sig_sel = 38627
N_mc_sig_gen = 2200000
#-----
N_norm = 2698130

eps_acc = ufloat(17.3e-2, 0)  # If no uncertainty is given


#calculating branch ratio
BR_Bc_Jpsipi = (R*BR_B_KJpsi)/fc_fu
BR_Bc_JpsiDst = BR_Bc_JpsiDst_Bc_Jpsipi*BR_Bc_Jpsipi
BR_Bc_JpsiDs = 2.8*BR_Bc_Jpsipi
BR_Bc_JpsiD = BR_Bc_JpsiDst * ((Vcd/Vcs)**2)



#calculating number of signal events
eps_norm = (N_mc_norm_sel/N_mc_norm_gen)*eps_acc
eps_sig = (N_mc_sig_sel/N_mc_sig_gen)*eps_acc

BR_B_KJpsi_mumu = BR_B_KJpsi*BR_Jpsi_mumu

super_br = BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu

BR_Bc_JpsiDs_kkpi = BR_Jpsi_mumu*BR_Ds_KKpi*(BR_Bc_JpsiDst/2)
# BR_Bc_JpsiDs_kkpi = BR_Jpsi_mumu*BR_Ds_KKpi*BR_Bc_JpsiDs
# eps_norm_new = (1135*BR_B_KJpsi_mumu*eps_norm)/(1.5*BR_Bc_JpsiDs_kkpi*N_norm*fc_fu)
eps_norm_new = (N_mc_norm_sel_new/N_mc_norm_gen_new)*eps_acc
N_norm_new = 770

N_ds = 1.5 * N_norm * 2.8 * R * BR_Ds_KKpi * (eps_norm_new/eps_norm)
N_ds_another = 1.5 * N_norm * ((BR_Bc_JpsiDs*BR_Ds_KKpi*BR_Jpsi_mumu)/(BR_B_KJpsi*BR_Jpsi_mumu))*(eps_norm_new/eps_norm)*fc_fu

N_sig = (BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu*N_ds_another*eps_sig)/(BR_Bc_JpsiDs_kkpi*eps_norm_new)
N_sig_prev = 1.5*((BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu*N_norm*eps_sig)/(BR_B_KJpsi_mumu*eps_norm))*fc_fu


print(f"BR_Bc_JpsiDs_kkpi: {BR_Bc_JpsiDs_kkpi}")
print(f"eps_norm_new: {eps_norm_new}")
print(f"number of signal for Ds: {N_ds}")
print(f"number of signal for Ds another one: {N_ds_another}")
print('-----------------------------')
print(f"BR_Bc_Jpsipi: {BR_Bc_Jpsipi}") 
print(f"BR_Bc_JpsiDst: {BR_Bc_JpsiDst}") 
print(f"BR_Bc_JpsiDs: {BR_Bc_JpsiDs}") 
print(f"BR_Bc_JpsiD: {BR_Bc_JpsiD}") 
print("--------------------------")
print(f"super_br: {super_br}") 
print("--------------------------")
print(f"eps_norm: {eps_norm}")
print(f"eps_sig: {eps_sig}")
print(f"BR_B_KJpsi_mumu: {BR_B_KJpsi_mumu}")
print(f"N_sig: {N_sig}")
print(f"N_sig_prev: {N_sig_prev}")

#FOR THE NEW DATA
# Out:
# BR_Bc_JpsiDs_kkpi: (8.1+/-1.5)e-06
# eps_norm_new: 0.0050213529032258055+/-0
# number of signal for Ds: 771+/-20
# number of signal for Ds another one: 771+/-20
# -----------------------------
# BR_Bc_Jpsipi: 0.000960+/-0.000033
# BR_Bc_JpsiDst: 0.0051+/-0.0009
# BR_Bc_JpsiDs: 0.00269+/-0.00009
# BR_Bc_JpsiD: 0.00024+/-0.00005
# --------------------------
# super_br: (3.8+/-0.7)e-07
# --------------------------
# eps_norm: 0.027222184333333333+/-0
# eps_sig: 0.003037486818181818+/-0
# BR_B_KJpsi_mumu: (5.96+/-0.13)e-05
# N_sig: 21.8+/-1.3
# N_sig_prev: 21+/-4

# %%
#FOR NEW NORMALISATION CHANNEL: Ds
#FOR PREVIOUS DATA

R = ufloat(0.683e-2, 0.018e-2)
BR_B_KJpsi = ufloat(1.02e-3, 0.019e-3)
fc_fu=ufloat(7.26e-3, 0.08e-3)
BR_Bc_JpsiDst_Bc_Jpsipi = ufloat(5.33, 0.96)
Vcd = ufloat(0.218, 0.004)
Vcs = ufloat(0.997, 0.017)
BR_Jpsi_mumu = ufloat(5.84e-2, 0.06e-2)

BR_D_D0pi = ufloat(67.7e-2, 0.5e-2)
BR_D0_Kpi = ufloat(3.9e-2, 0.09e-2)

BR_Ds_KKpi = ufloat(5.4e-2, 0)

# N_mc_norm_sel_new = 237253
N_mc_norm_sel_new = 187244
N_mc_norm_gen_new = 6200000
#-----
N_mc_norm_sel = 2360305
N_mc_norm_gen = 15000000
#-----
N_mc_sig_sel = 38627
N_mc_sig_gen = 2200000
#-----
N_norm = 2698130

eps_acc = ufloat(17.3e-2, 0)  # If no uncertainty is given


#calculating branch ratio
BR_Bc_Jpsipi = (R*BR_B_KJpsi)/fc_fu
BR_Bc_JpsiDst = BR_Bc_JpsiDst_Bc_Jpsipi*BR_Bc_Jpsipi
BR_Bc_JpsiDs = 2.8*BR_Bc_Jpsipi
BR_Bc_JpsiD = BR_Bc_JpsiDst * ((Vcd/Vcs)**2)



#calculating number of signal events
eps_norm = (N_mc_norm_sel/N_mc_norm_gen)*eps_acc
eps_sig = (N_mc_sig_sel/N_mc_sig_gen)*eps_acc

BR_B_KJpsi_mumu = BR_B_KJpsi*BR_Jpsi_mumu

super_br = BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu

BR_Bc_JpsiDs_kkpi = BR_Jpsi_mumu*BR_Ds_KKpi*BR_Bc_JpsiDs
# BR_Bc_JpsiDs_kkpi = BR_Jpsi_mumu*BR_Ds_KKpi*BR_Bc_JpsiDs
# eps_norm_new = (1135*BR_B_KJpsi_mumu*eps_norm)/(1.5*BR_Bc_JpsiDs_kkpi*N_norm*fc_fu)
eps_norm_new = (N_mc_norm_sel_new/N_mc_norm_gen_new)*eps_acc
N_norm_new = 339.7

N_ds = 1.5 * N_norm * 2.8 * R * BR_Ds_KKpi * (eps_norm_new/eps_norm)
N_ds_another = 1.5 * N_norm * ((BR_Bc_JpsiDs*BR_Ds_KKpi*BR_Jpsi_mumu)/(BR_B_KJpsi*BR_Jpsi_mumu))*(eps_norm_new/eps_norm)*fc_fu

N_sig = (BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu*N_norm_new*eps_sig)/(BR_Bc_JpsiDs_kkpi*eps_norm_new)
N_sig_prev = 1.5*((BR_Bc_JpsiD*BR_D_D0pi*BR_D0_Kpi*BR_Jpsi_mumu*N_norm*eps_sig)/(BR_B_KJpsi_mumu*eps_norm))*fc_fu


print(f"BR_Bc_JpsiDs_kkpi: {BR_Bc_JpsiDs_kkpi}")
print(f"eps_norm_new: {eps_norm_new}")
print(f"number of signal for Ds: {N_ds}")
print(f"number of signal for Ds another one: {N_ds_another}")
print('-----------------------------')
print(f"BR_Bc_Jpsipi: {BR_Bc_Jpsipi}") 
print(f"BR_Bc_JpsiDst: {BR_Bc_JpsiDst}") 
print(f"BR_Bc_JpsiDs: {BR_Bc_JpsiDs}") 
print(f"BR_Bc_JpsiD: {BR_Bc_JpsiD}") 
print("--------------------------")
print(f"super_br: {super_br}") 
print("--------------------------")
print(f"eps_norm_new: {eps_norm_new}")
print(f"eps_sig: {eps_sig}")
print(f"BR_B_KJpsi_mumu: {BR_B_KJpsi_mumu}")
print(f"N_sig: {N_sig}")
print(f"N_sig_prev: {N_sig_prev}")

#FOR THE NEW DATA
# Out:
# BR_Bc_JpsiDs_kkpi: (8.47+/-0.30)e-06
# eps_norm_new: 0.0052247116129032255+/-0
# number of signal for Ds: 802+/-21
# number of signal for Ds another one: 802+/-21
# -----------------------------
# BR_Bc_Jpsipi: 0.000960+/-0.000033
# BR_Bc_JpsiDst: 0.0051+/-0.0009
# BR_Bc_JpsiDs: 0.00269+/-0.00009
# BR_Bc_JpsiD: 0.00024+/-0.00005
# --------------------------
# super_br: (3.8+/-0.7)e-07
# --------------------------
# eps_norm_new: 0.0052247116129032255+/-0
# eps_sig: 0.003037486818181818+/-0
# BR_B_KJpsi_mumu: (5.96+/-0.13)e-05
# N_sig: 8.8+/-1.7
# N_sig_prev: 21+/-4

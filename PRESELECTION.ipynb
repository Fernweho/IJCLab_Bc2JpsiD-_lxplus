# %%
#LOADING LIBRARIES
import uproot
import matplotlib.pyplot as plt
import numpy as np

# %%
#SELECTIONS FOR DIFFERENT PARAMETERS
NEW_SELECTION_without_IPCHI2_OWNPV = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "

    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)
NEW_SELECTION_without_TRACK_CHI2NDOF = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "

    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)

NEW_SELECTION_without_PT = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "

    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)

NEW_SELECTION_without_mu_TRACK_CHI2NDOF = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "

    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)

NEW_SELECTION_without_mu_PT = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "

    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)

NEW_SELECTION_without_mu_IPCHI2_OWNPV = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "

    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)

NEW_SELECTION_without_Jpsi_M = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "

    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)

NEW_SELECTION_without_Bc_ENDVERTEX_CHI2 = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "

    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)

NEW_SELECTION_without_Bc_IPCHI2_OWNPV = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "

    "(Bc_DIRA_OWNPV > 0.998)"
)

NEW_SELECTION_without_Bc_DIRA_OWNPV = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) "
)

# %%
#PRESELECTION

THE_BIG_SELECTION_original = (
    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(delta_mass > 139) & (delta_mass < 151) & '
    '(D0_M > 1840) & (D0_M < 1890) & '
    '(K_IPCHI2_OWNPV > 3.) & (pi_IPCHI2_OWNPV > 3.) & '
    '(K_TRACK_CHI2NDOF < 1.7) & (pi_TRACK_CHI2NDOF < 1.7) & '
    '(K_PT > 250) & (pi_PT > 250) & '
    '(K_hasRich == 1) & (pi_hasRich == 1) & '
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(mp_TRACK_CHI2NDOF < 2.) & '
    '(mm_TRACK_CHI2NDOF < 2.) & '
    '(mp_isMuon == 1) & (mm_isMuon == 1) & '
    '(mp_PIDmu > 0) & (mm_PIDmu > 0) & '
    '(mp_PT > 700) & (mm_PT > 700) & '
    '(mp_IPCHI2_OWNPV > 2.) & (mm_IPCHI2_OWNPV > 2.) & '
    '(Jpsi_M < 3140.) & (Jpsi_M > 3040.) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'
    'pi_soft_PT > 250. &'
    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1 &'
    'Bc_ENDVERTEX_CHI2 < 4.2 &'
    'Bc_IPCHI2_OWNPV < 10. &'
    'Bc_DIRA_OWNPV > 0.99'
)

THE_BIG_SELECTION_psoft = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 3) & "
    "(K_TRACK_CHI2NDOF < 1.7) & (pi_TRACK_CHI2NDOF < 1.7) & "
    "(K_PT > 250) & (pi_PT > 250) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 2) & "
    "(mm_TRACK_CHI2NDOF < 2) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 700) & (mm_PT > 700) & "
    "(mp_IPCHI2_OWNPV > 2) & (mm_IPCHI2_OWNPV > 2) & "
    "(Jpsi_M < 3140) & (Jpsi_M > 3040) & "
    "(Bc_ENDVERTEX_CHI2 < 4.2) & "
    "(Bc_IPCHI2_OWNPV < 10) & "
    "(Bc_DIRA_OWNPV > 0.99)"
)

THE_BIG_SELECTION_looser = (
    "((Dst_M - D0_M) > 130) & ((Dst_M - D0_M) < 155) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 250) & (pi_PT > 250) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2) & (mm_IPCHI2_OWNPV > 2) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998)"
)

#SELECTION DEFINITION

NEW_SELECTION = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 3) & "
    "(K_TRACK_CHI2NDOF < 3.) & (pi_TRACK_CHI2NDOF < 3.) & "
    "(K_PT > 500.) & (pi_PT > 500.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 3.) & "
    "(mm_TRACK_CHI2NDOF < 3.) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 3.) & (mm_IPCHI2_OWNPV > 3.) & "
    "(Jpsi_M < 3127) & (Jpsi_M > 3067) & "
    "(Bc_ENDVERTEX_CHI2 < 4.) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"
    "(D0_ENDVERTEX_CHI2 < 8.) &"
    "(D0_M > 1835) & (D0_M < 1895) &"
    "(K_ProbNNghost < 0.3) & (pi_ProbNNghost < 0.3) & "
    "(mm_ProbNNghost < 0.3) & (mp_ProbNNghost < 0.3) & "
    "(K_ProbNNk > 0.1) & (pi_ProbNNpi > 0.1) & "
    "(Jpsi_ENDVERTEX_CHI2 < 9.) &"
    "(Dst_ENDVERTEX_CHI2 < 9.) &"
    "(abs(Dst_M - 2010.) < 30.) &"
    "(Dst_PT > 2500.) &"
    "(pi_soft_TRACK_CHI2NDOF < 3.) &"
    "(pi_soft_TRACK_GhostProb < 0.3)"
)
NEW_SELECTION_without_D0_ENDVERTEX_CHI2 = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"


    '(D0_M > 1840) & (D0_M < 1890) &'
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'
    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_D0_M = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'

    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'
    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_ProbNNghost = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(D0_M > 1840) & (D0_M < 1890) &'

    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'
    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_ProbNN = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(D0_M > 1840) & (D0_M < 1890) &'
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '

    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'
    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_Jpsi_ENDVERTEX_CHI2 = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(D0_M > 1840) & (D0_M < 1890) &'
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '

    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'
    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_Dst_ENDVERTEX_CHI2 = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(D0_M > 1840) & (D0_M < 1890) &'
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'

    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'
    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_Dst_M = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(D0_M > 1840) & (D0_M < 1890) &'
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'

    'Dst_PT > 2500. &'
    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_Dst_PT = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(D0_M > 1840) & (D0_M < 1890) &'
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'

    'pi_soft_TRACK_CHI2NDOF < 3. &'
    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_pi_soft_TRACK_CHI2NDOF = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(D0_M > 1840) & (D0_M < 1890) &'
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'

    'pi_soft_TRACK_GhostProb < 0.1'
)

NEW_SELECTION_without_pi_soft_TRACK_GhostProb = (
    "((Dst_M - D0_M) > 143) & ((Dst_M - D0_M) < 148) & "
    "(K_IPCHI2_OWNPV > 3) & (pi_IPCHI2_OWNPV > 4) & "
    "(K_TRACK_CHI2NDOF < 2.) & (pi_TRACK_CHI2NDOF < 2.) & "
    "(K_PT > 500.) & (pi_PT > 450.) & "
    "(K_hasRich == 1) & (pi_hasRich == 1) & "
    "(mp_TRACK_CHI2NDOF < 1.8) & "
    "(mm_TRACK_CHI2NDOF < 1.8) & "
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PIDmu > 0) & (mm_PIDmu > 0) & "
    "(mp_PT > 250) & (mm_PT > 250) & "
    "(mp_IPCHI2_OWNPV > 2.5) & (mm_IPCHI2_OWNPV > 2.5) & "
    "(Jpsi_M < 3120) & (Jpsi_M > 3065) & "
    "(Bc_ENDVERTEX_CHI2 < 3.7) & "
    "(Bc_IPCHI2_OWNPV < 8.) & "
    "(Bc_DIRA_OWNPV > 0.998) &"

    '(D0_ENDVERTEX_CHI2 < 8.) &'
    '(D0_M > 1840) & (D0_M < 1890) &'
    '(K_ProbNNghost < 0.1) & (pi_ProbNNghost < 0.1) & '
    '(K_ProbNNk > 0.4) & (pi_ProbNNpi > 0.4) & '
    '(Jpsi_ENDVERTEX_CHI2 < 9.) &'
    '(Dst_ENDVERTEX_CHI2 < 9.) &'
    'abs(Dst_M - 2010.) < 30. &'
    'Dst_PT > 2500. &'
    'pi_soft_TRACK_CHI2NDOF < 3.'

)

# %%
#LOADING DATASET

files_simu = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2011_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2012_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2015_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2016_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2017_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2018_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/mc/Bc2JpsiDst_Kpi/2018_MagUp.root',
]

files_real_data = [
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2011_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2011_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2012_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2012_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2015_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2015_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2016_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2017_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2018_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2018_MagUp.root',
]
# simu_data = uproot.concatenate(files_simu, cut = "(Bc_BKGCAT == 0)", library='pd')
real_data = uproot.concatenate(files_real_data, cut = NEW_SELECTION, library='pd')
real_data['delta_mass'] = real_data['Dst_M'] - real_data['D0_M']
# simu_data['delta_mass'] = simu_data['Dst_M'] - simu_data['D0_M']
# print(len(simu_data))
# print(len(simu_data.query(NEW_SELECTION)))
# Out:
# /tmp/ktrofimi/ipykernel_744933/563705569.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_data['delta_mass'] = real_data['Dst_M'] - real_data['D0_M']

# %%
files_real_data = [
    # '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2011_MagDown.root',
    # '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2011_MagUp.root',
    # '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2012_MagDown.root',
    # '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2012_MagUp.root',
    # '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2015_MagDown.root',
    # '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2015_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2016_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2016_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2017_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2017_MagUp.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2018_MagDown.root',
    '/eos/user/f/facglase/tuples/Bc2JpsiDst/data/Kpi/2018_MagUp.root',
]
real_data = uproot.concatenate(files_real_data, library='pd')
real_data['delta_mass'] = real_data['Dst_M'] - real_data['D0_M']
# Out:
# /tmp/ktrofimi/ipykernel_2937277/3980154869.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_data['delta_mass'] = real_data['Dst_M'] - real_data['D0_M']

# %%
#OVERALL PERFORMANCE
# Calculate the number of events before and after cutting for the simulation and real data
simu_before_cut = len(simu_data)
simu_after_cut = len(simu_data.query(NEW_SELECTION))

# Efficiency calculations
simu_efficiency = simu_after_cut / simu_before_cut if simu_before_cut else 0

print(f"Efficiency with cut for Kpi: {simu_efficiency*100:.2f}%")
print(f"number of events in simu selected for Kpi: {len(simu_data.query(NEW_SELECTION))}")
# Out:
# Efficiency with cut for Kpi: 47.64%
# number of events in simu selected for Kpi: 38627

# %%
#NEW SELECTION PERFORMANCE
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data['Bc_FullDTF_M'], range = (6250,6300), bins=100, histtype='step', label='Bc_FullDTF_M from MC')
ax.hist(simu_data.query(NEW_SELECTION)['Bc_FullDTF_M'], range = (6250,6300), bins=100, histtype='step', label='Bc_FullDTF_M from MC with applied selection')
# ax.hist(simu_data.query(THE_BIG_SELECTION_original)['Bc_FullDTF_M'], range = (6250,6300), bins=100, density = True, histtype='step', label='simu Bc_FullDTF_M with the old selection')
ax.set_xlabel('Bc_FullDTF_M, [MeV]')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Selection applied on MC')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#--------------(K_IPCHI2_OWNPV) & (pi_IPCHI2_OWNPV)---------------
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].hist(simu_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['K_IPCHI2_OWNPV'], range = (0,9), bins=100, density = True, histtype='step', label='simu K_IPCHI2_OWNPV')
ax[0].hist(real_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['K_IPCHI2_OWNPV'], range = (0,9), bins=100, density = True, histtype='step', label='real K_IPCHI2_OWNPV')
ax[0].axvline(x=3.0, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 3')
ax[0].set_xlabel('K_IPCHI2_OWNPV')
ax[0].set_ylabel('Events / 2 MeV')
ax[0].set_title('K_IPCHI2_OWNPV')
ax[0].legend(frameon=False)

ax[1].hist(simu_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['pi_IPCHI2_OWNPV'], range = (0,9), bins=100, density = True, histtype='step', label='simu pi_IPCHI2_OWNPV')
ax[1].hist(real_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['pi_IPCHI2_OWNPV'], range = (0,9), bins=100, density = True, histtype='step', label='real pi_IPCHI2_OWNPV')
ax[1].axvline(x=3.0, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 3')
ax[1].set_xlabel('pi_IPCHI2_OWNPV')
ax[1].set_ylabel('Events / 2 MeV')
ax[1].set_title('pi_IPCHI2_OWNPV')
ax[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#--------------(K_TRACK_CHI2NDOF) & (pi_TRACK_CHI2NDOF)---------------
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].hist(simu_data.query(NEW_SELECTION_without_TRACK_CHI2NDOF)['K_TRACK_CHI2NDOF'], range = (0,3), bins=100, density = True, histtype='step', label='simu K_TRACK_CHI2NDOF')
ax[0].hist(real_data.query(NEW_SELECTION_without_TRACK_CHI2NDOF)['K_TRACK_CHI2NDOF'], range = (0,3), bins=100, density = True, histtype='step', label='real K_TRACK_CHI2NDOF')
ax[0].axvline(x=1.7, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 1.7')
ax[0].set_xlabel('K_TRACK_CHI2NDOF')
ax[0].set_ylabel('Events / 2 MeV')
ax[0].set_title('K_TRACK_CHI2NDOF')
ax[0].legend(frameon=False)

ax[1].hist(simu_data.query(NEW_SELECTION_without_TRACK_CHI2NDOF)['pi_TRACK_CHI2NDOF'], range = (0,3), bins=100, density = True, histtype='step', label='simu pi_TRACK_CHI2NDOF')
ax[1].hist(real_data.query(NEW_SELECTION_without_TRACK_CHI2NDOF)['pi_TRACK_CHI2NDOF'], range = (0,3), bins=100, density = True, histtype='step', label='real pi_TRACK_CHI2NDOF')
ax[1].axvline(x=1.7, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 1.7')
ax[1].set_xlabel('pi_TRACK_CHI2NDOF')
ax[1].set_ylabel('Events / 2 MeV')
ax[1].set_title('pi_TRACK_CHI2NDOF')
ax[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#--------------(K_PT) & (pi_PT)---------------
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].hist(simu_data.query(NEW_SELECTION_without_PT)['K_PT'], range = (250,1500), bins=100, density = True, histtype='step', label='simu K_PT')
ax[0].hist(real_data.query(NEW_SELECTION_without_PT)['K_PT'], range = (250,1500), bins=100, density = True, histtype='step', label='real K_PT')
ax[0].axvline(x=250, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 250')
ax[0].set_xlabel('K_PT')
ax[0].set_ylabel('Events / 2 MeV')
ax[0].set_title('K_PT')
ax[0].legend(frameon=False)

ax[1].hist(simu_data.query(NEW_SELECTION_without_PT)['pi_PT'], range = (250,1500), bins=100, density = True, histtype='step', label='simu pi_PT')
ax[1].hist(real_data.query(NEW_SELECTION_without_PT)['pi_PT'], range = (250,1500), bins=100, density = True, histtype='step', label='real pi_PT')
ax[1].axvline(x=250, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 250')
ax[1].set_xlabel('pi_PT')
ax[1].set_ylabel('Events / 2 MeV')
ax[1].set_title('pi_PT')
ax[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#--------------(mm_TRACK_CHI2NDOF) & (mp_TRACK_CHI2NDOF)---------------
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].hist(simu_data.query(NEW_SELECTION_without_TRACK_CHI2NDOF)['mm_TRACK_CHI2NDOF'], range = (0,4), bins=100, density = True, histtype='step', label='simu mm_TRACK_CHI2NDOF')
ax[0].hist(real_data.query(NEW_SELECTION_without_TRACK_CHI2NDOF)['mm_TRACK_CHI2NDOF'], range = (0,4), bins=100, density = True, histtype='step', label='real mm_TRACK_CHI2NDOF')
ax[0].axvline(x=2, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 2')
ax[0].set_xlabel('mm_TRACK_CHI2NDOF')
ax[0].set_ylabel('Events / 2 MeV')
ax[0].set_title('mm_TRACK_CHI2NDOF')
ax[0].legend(frameon=False)

ax[1].hist(simu_data.query(NEW_SELECTION_without_TRACK_CHI2NDOF)['mp_TRACK_CHI2NDOF'], range = (0,4), bins=100, density = True, histtype='step', label='simu mp_TRACK_CHI2NDOF')
ax[1].hist(real_data.query(NEW_SELECTION_without_TRACK_CHI2NDOF)['mp_TRACK_CHI2NDOF'], range = (0,4), bins=100, density = True, histtype='step', label='real mp_TRACK_CHI2NDOF')
ax[1].axvline(x=2, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 2')
ax[1].set_xlabel('mp_TRACK_CHI2NDOF')
ax[1].set_ylabel('Events / 2 MeV')
ax[1].set_title('mp_TRACK_CHI2NDOF')
ax[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#--------------(mm_PT) & (mp_PT)---------------
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].hist(simu_data.query(NEW_SELECTION_without_PT)['mm_PT'], range = (500,1000), bins=100, density = True, histtype='step', label='simu mm_PT')
ax[0].hist(real_data.query(NEW_SELECTION_without_PT)['mm_PT'], range = (500,1000), bins=100, density = True, histtype='step', label='real mm_PT')
ax[0].axvline(x=700, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 700')
ax[0].set_xlabel('mm_PT')
ax[0].set_ylabel('Events / 2 MeV')
ax[0].set_title('mm_PT')
ax[0].legend(frameon=False)

ax[1].hist(simu_data.query(NEW_SELECTION_without_PT)['mp_PT'], range = (500,1000), bins=100, density = True, histtype='step', label='simu mp_PT')
ax[1].hist(real_data.query(NEW_SELECTION_without_PT)['mp_PT'], range = (500,1000), bins=100, density = True, histtype='step', label='real mp_PT')
ax[1].axvline(x=700, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 700')
ax[1].set_xlabel('mp_PT')
ax[1].set_ylabel('Events / 2 MeV')
ax[1].set_title('mp_PT')
ax[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#--------------(mm_IPCHI2_OWNPV) & (mp_IPCHI2_OWNPV)---------------
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].hist(simu_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['mm_IPCHI2_OWNPV'], range = (1.5,9), bins=100, density = True, histtype='step', label='simu mm_IPCHI2_OWNPV')
ax[0].hist(real_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['mm_IPCHI2_OWNPV'], range = (1.5,9), bins=100, density = True, histtype='step', label='real mm_IPCHI2_OWNPV')
ax[0].axvline(x=2, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 2')
ax[0].set_xlabel('mm_IPCHI2_OWNPV')
ax[0].set_ylabel('Events / 2 MeV')
ax[0].set_title('mm_IPCHI2_OWNPV')
ax[0].legend(frameon=False)

ax[1].hist(simu_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['mp_IPCHI2_OWNPV'], range = (1.5,9), bins=100, density = True, histtype='step', label='simu mp_IPCHI2_OWNPV')
ax[1].hist(real_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['mp_IPCHI2_OWNPV'], range = (1.5,9), bins=100, density = True, histtype='step', label='real mp_IPCHI2_OWNPV')
ax[1].axvline(x=2, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 2')
ax[1].set_xlabel('mp_IPCHI2_OWNPV')
ax[1].set_ylabel('Events / 2 MeV')
ax[1].set_title('mp_IPCHI2_OWNPV')
ax[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#--------------(delta_mass)---------------
fig, ax = plt.subplots(figsize=(12, 6))

# ax.hist(simu_data.query(NEW_SELECTION)['delta_mass'], bins=100, density = True, histtype='step', label='simu delta_mass')
ax.hist(real_data.query(NEW_SELECTION)['delta_mass'], bins=100, range = (120, 170), histtype='step', label='Dst_M - D0_M')
# ax.axvline(x=3140, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 3140')
# ax.axvline(x=3040, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 3040')
ax.set_xlabel('delta_mass, [MeV]')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Difference between mass of D* and mass of D0 for data with applied Preselection')
ax.legend(frameon=False)



plt.tight_layout()
plt.show()

# %%
#--------------(Jpsi_M)---------------
fig, ax = plt.subplots(figsize=(12, 6))

# ax.hist(simu_data.query(NEW_SELECTION)['Jpsi_M'], bins=100, density = True, histtype='step', label='simu Jpsi_M')
ax.hist(real_data.query(NEW_SELECTION)['Jpsi_M'], bins=100, range = (2800, 3300), histtype='step', label='mass of J/psi')
# ax.axvline(x=3140, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 3140')
# ax.axvline(x=3040, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 3040')
ax.set_xlabel('Jpsi_M, [MeV]')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Mass of J/psi for data with applied Preselection')
ax.legend(frameon=False)



plt.tight_layout()
plt.show()

# %%
#--------------(D0_M)---------------
fig, ax = plt.subplots(figsize=(12, 6))

# ax.hist(simu_data.query(NEW_SELECTION)['D0_M'], bins=100, density = True, histtype='step', label='simu D0_M')
ax.hist(real_data.query(NEW_SELECTION)['D0_M'], bins=100, range = (1600, 2100), histtype='step', label='mass of D0')
# ax.axvline(x=3140, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 3140')
# ax.axvline(x=3040, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 3040')
ax.set_xlabel('D0_M, [MeV]')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Mass of D0 for data with applied Preselection')
ax.legend(frameon=False)



plt.tight_layout()
plt.show()

# %%
#--------------(Bc_ENDVERTEX_CHI2)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['Bc_ENDVERTEX_CHI2'], range = (1,6), bins=100, density = True, histtype='step', label='simu Bc_ENDVERTEX_CHI2')
ax.hist(real_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['Bc_ENDVERTEX_CHI2'], range = (1,6), bins=100, density = True, histtype='step', label='real Bc_ENDVERTEX_CHI2')
ax.axvline(x=4.2, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 4.2')
ax.set_xlabel('Bc_ENDVERTEX_CHI2')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Bc_ENDVERTEX_CHI2')
ax.legend(frameon=False)



plt.tight_layout()
plt.show()

# %%
#--------------(Bc_IPCHI2_OWNPV)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['Bc_IPCHI2_OWNPV'], range = (1,15), bins=100, density = True, histtype='step', label='simu Bc_IPCHI2_OWNPV')
ax.hist(real_data.query(NEW_SELECTION_without_IPCHI2_OWNPV)['Bc_IPCHI2_OWNPV'], range = (1,15), bins=100, density = True, histtype='step', label='real Bc_IPCHI2_OWNPV')
ax.axvline(x=10, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 10')
ax.set_xlabel('Bc_IPCHI2_OWNPV')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Bc_IPCHI2_OWNPV')
ax.legend(frameon=False)



plt.tight_layout()
plt.show()

# %%
#--------------(Bc_DIRA_OWNPV)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_Bc_DIRA_OWNPV)['Bc_DIRA_OWNPV'], range = (0.975,1), bins=100, density = True, histtype='step', label='simu Bc_DIRA_OWNPV')
ax.hist(real_data.query(NEW_SELECTION_without_Bc_DIRA_OWNPV)['Bc_DIRA_OWNPV'], range = (0.975,1), bins=100, density = True, histtype='step', label='real Bc_DIRA_OWNPV')
ax.axvline(x=0.99, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 0.99')
ax.set_xlabel('Bc_DIRA_OWNPV')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Bc_DIRA_OWNPV')
ax.legend(frameon=False)



plt.tight_layout()
plt.show()

# %%
#--------------(D0_ENDVERTEX_CHI2)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_D0_ENDVERTEX_CHI2)['D0_ENDVERTEX_CHI2'], range = (0.,15), bins=100, density = True, histtype='step', label='simu D0_ENDVERTEX_CHI2')
ax.hist(real_data.query(NEW_SELECTION_without_D0_ENDVERTEX_CHI2)['D0_ENDVERTEX_CHI2'], range = (0.,15), bins=100, density = True, histtype='step', label='real D0_ENDVERTEX_CHI2')
ax.axvline(x=9., color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 9.')
ax.set_xlabel('D0_ENDVERTEX_CHI2')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('D0_ENDVERTEX_CHI2')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#--------------(D0_M)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_D0_M)['D0_M'], range = (1800.,2000.), bins=100, density = True, histtype='step', label='simu D0_M')
ax.hist(real_data.query(NEW_SELECTION_without_D0_M)['D0_M'], range = (1800.,2000.), bins=100, density = True, histtype='step', label='real D0_M')
ax.axvline(x=1890, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 1890')
ax.axvline(x=1830, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 1830')
ax.set_xlabel('D0_M')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('D0_M')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#--------------(K_ProbNNghost) & (pi_ProbNNghost)---------------
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].hist(simu_data.query(NEW_SELECTION_without_ProbNNghost)['K_ProbNNghost'], range = (0,0.6), bins=100, density = True, histtype='step', label='simu K_ProbNNghost')
ax[0].hist(real_data.query(NEW_SELECTION_without_ProbNNghost)['K_ProbNNghost'], range = (0,0.6), bins=100, density = True, histtype='step', label='real K_ProbNNghost')
ax[0].axvline(x=0.3, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 0.3')
ax[0].set_xlabel('K_ProbNNghost')
ax[0].set_ylabel('Events / 2 MeV')
ax[0].set_title('K_ProbNNghost')
ax[0].legend(frameon=False)

ax[1].hist(simu_data.query(NEW_SELECTION_without_ProbNNghost)['pi_ProbNNghost'], range = (0,0.6), bins=100, density = True, histtype='step', label='simu pi_ProbNNghost')
ax[1].hist(real_data.query(NEW_SELECTION_without_ProbNNghost)['pi_ProbNNghost'], range = (0,0.6), bins=100, density = True, histtype='step', label='real pi_ProbNNghost')
ax[1].axvline(x=0.3, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 0.3')
ax[1].set_xlabel('pi_ProbNNghost')
ax[1].set_ylabel('Events / 2 MeV')
ax[1].set_title('pi_ProbNNghost')
ax[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#--------------(K_ProbNNk) & (pi_ProbNNpi)---------------
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].hist(simu_data.query(NEW_SELECTION_without_ProbNN)['K_ProbNNk'], range = (0,1.), bins=100, density = True, histtype='step', label='simu K_ProbNNk')
ax[0].hist(real_data.query(NEW_SELECTION_without_ProbNN)['K_ProbNNk'], range = (0,1.), bins=100, density = True, histtype='step', label='real K_ProbNNk')
ax[0].axvline(x=0.1, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 0.1')
ax[0].set_xlabel('K_ProbNNk')
ax[0].set_ylabel('Events / 2 MeV')
ax[0].set_title('K_ProbNNk')
ax[0].legend(frameon=False)

ax[1].hist(simu_data.query(NEW_SELECTION_without_ProbNN)['pi_ProbNNpi'], range = (0,1.), bins=100, density = True, histtype='step', label='simu pi_ProbNNpi')
ax[1].hist(real_data.query(NEW_SELECTION_without_ProbNN)['pi_ProbNNpi'], range = (0,1.), bins=100, density = True, histtype='step', label='real pi_ProbNNpi')
ax[1].axvline(x=0.1, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 0.1')
ax[1].set_xlabel('pi_ProbNNpi')
ax[1].set_ylabel('Events / 2 MeV')
ax[1].set_title('pi_ProbNNpi')
ax[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#--------------(Jpsi_ENDVERTEX_CHI2)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_Jpsi_ENDVERTEX_CHI2)['Jpsi_ENDVERTEX_CHI2'], range = (1.,10.), bins=100, density = True, histtype='step', label='simu Jpsi_ENDVERTEX_CHI2')
ax.hist(real_data.query(NEW_SELECTION_without_Jpsi_ENDVERTEX_CHI2)['Jpsi_ENDVERTEX_CHI2'], range = (1.,10.), bins=100, density = True, histtype='step', label='real Jpsi_ENDVERTEX_CHI2')
ax.axvline(x=5., color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 5.')
ax.set_xlabel('Jpsi_ENDVERTEX_CHI2')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Jpsi_ENDVERTEX_CHI2')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#--------------(Dst_ENDVERTEX_CHI2)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_Dst_ENDVERTEX_CHI2)['Dst_ENDVERTEX_CHI2'], range = (1.,10.), bins=100, density = True, histtype='step', label='simu Dst_ENDVERTEX_CHI2')
ax.hist(real_data.query(NEW_SELECTION_without_Dst_ENDVERTEX_CHI2)['Dst_ENDVERTEX_CHI2'], range = (1.,10.), bins=100, density = True, histtype='step', label='real Dst_ENDVERTEX_CHI2')
ax.axvline(x=9., color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 9.')
ax.set_xlabel('Dst_ENDVERTEX_CHI2')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Dst_ENDVERTEX_CHI2')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#--------------(Dst_M)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(abs(simu_data.query(NEW_SELECTION_without_Dst_M)['Dst_M'])-2010, range = (1.,90.), bins=100, density = True, histtype='step', label='simu Dst_M')
ax.hist(abs(real_data.query(NEW_SELECTION_without_Dst_M)['Dst_M'])-2010, range = (1.,90.), bins=100, density = True, histtype='step', label='real Dst_M')
ax.axvline(x=40, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 40')
ax.set_xlabel('abs(Dst_M - 2010.)')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('abs(Dst_M - 2010.)')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#--------------(Dst_PT)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_Dst_PT)['Dst_PT'], range = (1000.,5000.), bins=100, density = True, histtype='step', label='simu Dst_PT')
ax.hist(real_data.query(NEW_SELECTION_without_Dst_PT)['Dst_PT'], range = (1000.,5000.), bins=100, density = True, histtype='step', label='real Dst_PT')
ax.axvline(x=2700., color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION > 2700.')
ax.set_xlabel('Dst_PT')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Dst_PT')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#--------------(pi_soft_TRACK_CHI2NDOF)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_pi_soft_TRACK_CHI2NDOF)['pi_soft_TRACK_CHI2NDOF'], range = (1.,4.), bins=100, density = True, histtype='step', label='simu pi_soft_TRACK_CHI2NDOF')
ax.hist(real_data.query(NEW_SELECTION_without_pi_soft_TRACK_CHI2NDOF)['pi_soft_TRACK_CHI2NDOF'], range = (1.,4.), bins=100, density = True, histtype='step', label='real pi_soft_TRACK_CHI2NDOF')
ax.axvline(x=2., color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 2.')
ax.set_xlabel('pi_soft_TRACK_CHI2NDOF')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('pi_soft_TRACK_CHI2NDOF')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#--------------(pi_soft_TRACK_GhostProb)---------------
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(simu_data.query(NEW_SELECTION_without_pi_soft_TRACK_GhostProb)['pi_soft_TRACK_GhostProb'], range = (0.,0.6), bins=100, density = True, histtype='step', label='simu pi_soft_TRACK_GhostProb')
ax.hist(real_data.query(NEW_SELECTION_without_pi_soft_TRACK_GhostProb)['pi_soft_TRACK_GhostProb'], range = (0.,0.6), bins=100, density = True, histtype='step', label='real pi_soft_TRACK_GhostProb')
ax.axvline(x=0.4, color='red', linestyle='--', label='Threshold from THE_BIG_SELECTION < 0.4')
ax.set_xlabel('pi_soft_TRACK_GhostProb')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('pi_soft_TRACK_GhostProb')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
#D0_Mass comparing
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(real_data['D0_M'], bins=100, density = True, histtype='step', label='D0_M')
ax.hist(real_data.query(NEW_SELECTION)['D0_M'], bins=100, density = True, histtype='step', label='D0_M with THE_BIG_SELECTION')
ax.set_xlabel('D0_M [MeV]')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('D0_Mass comparing')

ax.legend(frameon=False)

plt.tight_layout()

plt.show()

# %%
#J/psi MASS
#Comparing Kpi cuts for D0
# bin_edges = np.histogram_bin_edges(
#     np.concatenate([
#         simu_data['D0_M'],
#         real_data['D0_M'],
#         simu_data.query(NEW_SELECTION)['D0_M'],
#         real_data.query(NEW_SELECTION)['D0_M']
#     ]),
#     bins=100,
# )
fig, axes = plt.subplots(2, 2, figsize=(12, 6))
#for D0:
axes[0,0].hist(simu_data['D0_M'], range = (1830, 1890), bins=100, histtype='step', label='MC D0 mass')
axes[0,0].set_xlabel('D0 mass [MeV]')
axes[0,0].set_ylabel('Events / 2 MeV')
axes[0,0].set_title('SIMULATION: D0 mass without cutting')
axes[0,0].legend(frameon=False)

axes[0,1].hist(real_data['D0_M'], range = (1830, 1890), bins=100, histtype='step', label='real data D0 mass')
axes[0,1].set_xlabel('D0 mass [MeV]')
axes[0,1].set_ylabel('Events / 2 MeV')
axes[0,1].set_title('REAL DATA: D0 mass without cutting')
axes[0,1].legend(frameon=False)
#for cut:
axes[1,0].hist(simu_data.query(NEW_SELECTION)['D0_M'], range = (1830, 1890), bins=100, histtype='step', label='MC D0 mass with the cut')
axes[1,0].set_xlabel('D0 mass [MeV]')
axes[1,0].set_ylabel('Events / 2 MeV')
axes[1,0].set_title('SIMULATION: D0 mass with the Selection')
axes[1,0].legend(frameon=False)

axes[1,1].hist(real_data.query(NEW_SELECTION)['D0_M'], range = (1830, 1890), bins=100, histtype='step', label='real data D0 mass with the cut')
axes[1,1].set_xlabel('D0 mass [MeV]')
axes[1,1].set_ylabel('Events / 2 MeV')
axes[1,1].set_title('REAL DATA: D0 mass with the Selection')
axes[1,1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
print(len(real_data))
print(len(real_data.query(NEW_SELECTION)))
# Out:
# 1369
# 1357

# %%
#FOR PIONS
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# --- First plot (pi_IPCHI2_OWNPV) ---
axes[0].hist(simu_data.query(THE_BIG_SELECTION)['pi_IPCHI2_OWNPV'], 
             density=True, bins=100, histtype='step', range=(0, 150), label='SIMULATION')
axes[0].hist(real_data.query(THE_BIG_SELECTION)['pi_IPCHI2_OWNPV'], 
             density=True, bins=100, histtype='step', range=(0, 150), label='background DATA')
axes[0].axvline(x=1.0, color='red', linestyle='--', label='Threshold (1.0)')
axes[0].set_xlabel('pi_IPCHI2_OWNPV')
axes[0].set_ylabel('Normalized Events')
axes[0].set_title('pi_IPCHI2_OWNPV: SIMULATION vs background DATA')
axes[0].legend(frameon=False)

# --- Second plot (pi_soft_IPCHI2_OWNPV) ---
axes[1].hist(simu_data.query(THE_BIG_SELECTION)['pi_soft_IPCHI2_OWNPV'], 
             density=True, bins=100, histtype='step', range=(0, 150), label='SIMULATION')
axes[1].hist(real_data.query(THE_BIG_SELECTION)['pi_soft_IPCHI2_OWNPV'], 
             density=True, bins=100, histtype='step', range=(0, 150), label='background DATA')
axes[1].axvline(x=1.0, color='red', linestyle='--', label='Threshold (1.0)')
axes[1].set_xlabel('pi_soft_IPCHI2_OWNPV')
axes[1].set_ylabel('Normalized Events')
axes[1].set_title('pi_soft_IPCHI2_OWNPV: SIMULATION vs background DATA')
axes[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#FOR PIONS
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# --- First plot (pi_TRACK_CHI2NDOF) ---
axes[0].hist(simu_data.query(THE_BIG_SELECTION)['pi_TRACK_CHI2NDOF'], 
             density=True, bins=100, histtype='step', range=(0, 3), label='SIMULATION')
axes[0].hist(simu_bckg_data.query(THE_BIG_SELECTION)['pi_TRACK_CHI2NDOF'], 
             density=True, bins=100, histtype='step', range=(0, 3), label='background DATA')
axes[0].axvline(x=1.0, color='red', linestyle='--', label='Threshold (1.0)')
axes[0].set_xlabel('pi_TRACK_CHI2NDOF')
axes[0].set_ylabel('Normalized Events')
axes[0].set_title('pi_TRACK_CHI2NDOF: SIMULATION vs background DATA')
axes[0].legend(frameon=False)

# --- Second plot (pi_soft_TRACK_CHI2NDOF) ---
axes[1].hist(simu_data.query(THE_BIG_SELECTION)['pi_soft_TRACK_CHI2NDOF'], 
             density=True, bins=100, histtype='step', range=(0, 3), label='SIMULATION')
axes[1].hist(simu_bckg_data.query(THE_BIG_SELECTION)['pi_soft_TRACK_CHI2NDOF'], 
             density=True, bins=100, histtype='step', range=(0, 3), label='background DATA')
axes[1].axvline(x=1.0, color='red', linestyle='--', label='Threshold (1.0)')
axes[1].set_xlabel('pi_soft_TRACK_CHI2NDOF')
axes[1].set_ylabel('Normalized Events')
axes[1].set_title('pi_soft_TRACK_CHI2NDOF: SIMULATION vs background DATA')
axes[1].legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
#FOR PIONS
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# --- First plot (pi_PT) ---
axes[0].hist(simu_data.query(THE_BIG_SELECTION)['pi_PT'], 
             density=True, bins=100, histtype='step', range=(200, 3000), label='SIMULATION')
axes[0].hist(real_data.query(THE_BIG_SELECTION)['pi_PT'], 
             density=True, bins=100, histtype='step', range=(200, 3000), label='background DATA')
# axes[0].axvline(x=1.0, color='red', linestyle='--', label='Threshold (1.0)')
axes[0].set_xlabel('pi_PT')
axes[0].set_ylabel('Normalized Events')
axes[0].set_title('pi_PT: SIMULATION vs background DATA')
axes[0].legend(frameon=False)

# --- Second plot (pi_soft_PT) ---
axes[1].hist(simu_data.query(THE_BIG_SELECTION)['pi_soft_PT'], 
             density=True, bins=100, histtype='step', range=(200, 3000), label='SIMULATION')
axes[1].hist(real_data.query(THE_BIG_SELECTION)['pi_soft_PT'], 
             density=True, bins=100, histtype='step', range=(200, 3000), label='background DATA')
# axes[1].axvline(x=1., color='red', linestyle='--', label='Threshold (1.200)')
axes[1].set_xlabel('pi_soft_PT')
axes[1].set_ylabel('Normalized Events')
axes[1].set_title('pi_soft_PT: SIMULATION vs background DATA')
axes[1].legend(frameon=False)

plt.tight_layout()
plt.show()

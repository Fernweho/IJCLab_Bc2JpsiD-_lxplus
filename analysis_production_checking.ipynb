# %%
#LOADING LIBRARIES
import uproot
import matplotlib.pyplot as plt
import numpy as np

# %%
#SELECTION DEFINITION

Ds_SELECTION = (
    "(mp_isMuon == 1) & (mm_isMuon == 1) & "
    "(mp_PT > 550) & (mm_PT > 550) & "
    "(Jpsi_M < 3150) & (Jpsi_M > 3040) & "
    "(Jpsi_ENDVERTEX_CHI2 < 9.) &"
    "(pi_PT > 1700.) & "
    "(pi_TRACK_CHI2NDOF < 3.) & "
    "(pi_ProbNNghost < 0.4) &"
    "(pi_IPCHI2_OWNPV > 9) &"
    "(Bc_ENDVERTEX_CHI2 < 9.) & "
    "(Bc_IPCHI2_OWNPV < 25.) & "
    "(Kp_PT > 1000.) & (Km_PT > 1000.) &"
    "(Kp_P > 1000.) & (Km_P > 1000.) &"
    "(pi_P > 1000.) & "
    "(Ds_ENDVERTEX_CHI2 < 16.) &"
    "(Ds_PT > 1000.) &"
    "(Ds_M > 1944) & (Ds_M < 1994) &"
    "(Bc_DIRA_OWNPV > 0.99)"
)

# %%
real_Ds = uproot.concatenate(
    {'/afs/cern.ch/user/k/ktrofimi/AnalysisProductions/local-tests/Bc2JpsiDst-2025-02-27-13-25-38/output/00012345_00006789_1.BC2JPSIDS2KKPI.ROOT': 'Bc2JpsiDs_Ds2KKpi/DecayTree'}, 
    library='pd'
)

# %%
MC_Ds = uproot.concatenate(
    {'/afs/cern.ch/user/k/ktrofimi/AnalysisProductions/local-tests/Bc2JpsiDst-2025-02-27-10-18-18/output/00012345_00006789_1.BC2JPSIDS2KKPI_MC.ROOT': 'Bc2JpsiDs_Ds2KKpi/DecayTree'}, 
    library='pd'
)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.hist(real_Ds['Ds_M'], bins=100, histtype='step', label='simu Ds_M')
ax.set_xlabel('Ds_M')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Ds_M')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.hist(real_Ds['Jpsi_M'], bins=100, histtype='step', label='simu Jpsi_M')
ax.set_xlabel('Jpsi_M')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Jpsi_M')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.hist(real_Ds['Bc_M'], bins=100, histtype='step', label='simu Bc_M')
ax.set_xlabel('Bc_M')
ax.set_ylabel('Events / 2 MeV')
ax.set_title('Bc_M')
ax.legend(frameon=False)


plt.tight_layout()
plt.show()
